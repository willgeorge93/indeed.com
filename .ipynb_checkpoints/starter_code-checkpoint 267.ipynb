# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
#
# # Web Scraping for Indeed.com and Predicting Salaries

# %% [markdown]
# ## Project Overview
#
# ### SCRAPE INDEED FOR DATA SCIENCE RELATED JOB POSTS IN LONDON
# ### WEBSCRAPING IS CONSIDERED FAR BETTER IF YOU SIMPLY REQUIRE DATA FROM THE WEBSITE, HOWEVER IF YOU NEED TO INTERACT WITH THE WEBSITE (i.e. traverse different pages) THEY YOU NEED TO USE APIs.
#
# #### FOR THIS PROJECT I'M GOING TO WEBSCRAPE INDEED USINGTHE REQUESTS LIBRARY & BEAUTIFUL SOUP.
#
# ##### ALTHOUGH APIs CAN INTERACT WITH THE SEARCH BAR AND FILTERS ETC?

# %% [markdown]
# ### Business Case Overview
#
# You're working as a data scientist for a contracting firm that's rapidly expanding. Now that they have their most valuable employee (you!), they need to leverage data to win more contracts. Your firm offers technology and scientific solutions and wants to be competitive in the hiring market. Your principal wants you to
#
#    - determine the industry factors that are most important in predicting the salary amounts for these data.
#
# To limit the scope, your principal has suggested that you *focus on data-related job postings*, e.g. data scientist, data analyst, research scientist, business intelligence, and any others you might think of. You may also want to decrease the scope by *limiting your search to a single region.*
#
# Hint: Aggregators like [Indeed.com](https://www.indeed.com) regularly pool job postings from a variety of markets and industries.
#
# **Goal:** Scrape your own data from a job aggregation tool like Indeed.com in order to collect the data to best answer this question.
#
# ---
#
# ### Directions
#
# In this project you will be leveraging a variety of skills. The first will be to use the web-scraping and/or API techniques you've learned to collect data on data jobs from Indeed.com or another aggregator. Once you have collected and cleaned the data, you will use it to address the question above.

# %% [markdown]
# ### Factors that impact salary
#
# To predict salary the most appropriate approach would be a regression model.
# Here instead we just want to estimate which factors (like location, job title, job level, industry sector) lead to high or low salary and work with a classification model. To do so, split the salary into two groups of high and low salary, for example by choosing the median salary as a threshold (in principle you could choose any single or multiple splitting points).
#
# Use all the skills you have learned so far to build a predictive model.
# Whatever you decide to use, the most important thing is to justify your choices and interpret your results. *Communication of your process is key.* Note that most listings **DO NOT** come with salary information. You'll need to be able to extrapolate or predict the expected salaries for these listings.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10").
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)
#
# The URL here has many query parameters:
#
# - `q` for the job search
# - This is followed by "+20,000" to return results with salaries (or expected salaries >$20,000)
# - `l` for a location
# - `start` for what result number to start on

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import time
from tqdm import tqdm
import numpy as np
import pandas as pd
import math

# %%
# titles = []
# locations = []
# companies = []
# descriptions = []
# salaries = []
# competencies = []
# post_age = []
             
# base_url = 'https://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10'
# r = requests.get(base_url)
# soup = BeautifulSoup(r.text, 'html.parser')
# num_pages = math.ceil(int(soup.find('div', attrs={'id': 'searchCountPages'}).text.split('of')[1].strip('jobs').strip(' ').replace(',', ''))/15)

# for i in tqdm(range(num_pages)):
#     url = (f'https://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start={i*10}')
#     r = requests.get(url)
#     soup = BeautifulSoup(r.text, 'html.parser')
#     for post in soup.find_all('div', attrs={'class':'jobsearch-SerpJobCard'}):
#         try:
#             titles.append(post.find('h2', attrs={'class':'title'}).text.replace('\n', ' ').strip())
#         except:
#             titles.append(np.nan)
        
#         try:
#             companies.append(post.find('span', attrs={'class':'company'}).text.strip('\n'))
#         except:
#             companies.append(np.nan)
            
#         try:
#             locations.append(post.find('span', attrs={'class':'location'}).text)
#         except:
#             locations.append(np.nan)
            
#         try:
#             bullets = post.find('div', attrs={'class':'summary'})
#             descriptions.append(bullets.find('li').text)
#         except:
#             descriptions.append(np.nan)
        
#         try:
#             post_age.append(post.find('span', attrs={'class':'date'}).text)
#         except:
#             post_age.append(np.nan)
        
#         time.sleep(2)
    
# jobs = pd.DataFrame({'job_title': titles,
#                      'location': locations,
#                      'company': companies,
#                      'job_description': descriptions,
#                      'post_age': post_age})

# jobs

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is in a `span` with `class='salaryText'`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element='jobTitle'`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.
# - Decide which other components could be relevant, for example the region or the summary of the job advert.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# Example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - **Make sure these functions are robust and can handle cases where the data/field may not be available.**
#     - Remember to check if a field is empty or `None` for attempting to call methods on it.
#     - Remember to use `try/except` if you anticipate errors.
# - **Test** the functions on the results above and simple examples.

# %%
def extract_location(result):
    try:
        return result.find('span', attrs={'class': 'location'}).text
    except:
        return np.nan

# %%
def extract_company(result):
    try:
        return result.find('span', attrs={'class': 'company'}).text.strip('\n')
    except:
        return np.nan

# %%
def extract_job_title(result):
    try:
        return result.find('a', attrs={'class': 'jobtitle', 'data-tn-element': 'jobTitle'}).text.replace('\n', ' ').strip()
    except:
        return np.nan

# %%
def extract_salary(result):
    try:
        return result.find('span', attrs={'class': 'salaryText'}).text.replace('$', '').replace(',', '').strip('\n')
    except:
        return np.nan

# %%
## YOUR CODE HERE

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# ### Complete the following code to collect results from multiple cities and starting points.
# - Enter your city below to add it to the search.
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different.

# %%
['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Seattle', 
    'Los+Angeles', 'Philadelphia', 'Atlanta', 'Dallas', 'Pittsburgh', 
    'Portland', 'Phoenix', 'Denver', 'Houston', 'Miami', 'San+Antonio']

# %%
YOUR_CITY = 'London'

# %%
ANOTHER_CITY = 'San+Antonio'

# %%
MY_HOME_CITY =

# %%
def page_getter(city):
    url = url = f"http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={city}&start=0"
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')
    return math.ceil(int(soup.find('div', attrs={'id': 'searchCountPages'}).text.split('of')[1].strip('jobs').strip(' ').replace(',', ''))/15)

# %%
from collections import defaultdict
from IPython.display import clear_output

max_results_per_city = 5000 # Set this to a high-value (5000) to generate more results. 
# Crawling more results, will also take much longer. First test your code on a small number of results and then expand.

results = defaultdict(list)
status = defaultdict(list)

captcha=False

# while loop for repeating until certain amount of data is scraped - storing the city and result each time so we can continue from this point
# countries = [england, united_states, singapore]
# england = ['Chester' 'London', 'Manchester', 'Liverpool', 'Leeds', 'York', 'Bradford', 
#     'Milton+Keynes', 'Reading', 'Birmingham', 'Cardiff', 'Wolverhampton', 
#     'Edinburgh', 'Glasgow', 'Huddersfield', 'Crewe', 'Warwick', 'Oxford', 
#     'Cambridge', 'Bournemouth']

for city in set(['London', 'Liverpool']):
#     pages = page_getter(city)
    for start in tqdm(range(0, max_results_per_city, 10)):
        url = f"https://uk.indeed.com/jobs?q=data+scientist&l={city}&start={start}"
        result = requests.get(url)
        status[city].append(result.status_code)
        soup = BeautifulSoup(result.text, 'html.parser')
        if 'hCaptcha' not in str(soup.prettify):
            for post in soup.find_all('div', attrs={'class':'jobsearch-SerpJobCard'}):
                results['title'].append(extract_job_title(post))
                results['company'].append(extract_company(post))
                results['location'].append(extract_location(post))
                results['country'].append('england')
                results['salary'].append(extract_salary(post))
            time.sleep(30)
        else:
            print('Caught')
            city_cursor = city
            page_cursor = start
            captcha=True
            break
    if captcha==True:
        break
    time.sleep(20)


print(f'Stopped at {city_cursor}, page {int(page_cursor/10)}')
# Out:
# 100%|██████████| 500/500 [5:47:36<00:00, 41.71s/it]
# 100%|██████████| 500/500 [5:33:41<00:00, 40.04s/it]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-de893b15a402> in <module>
#      43
#      44
# ---> 45 print(f'Stopped at {city_cursor}, page {int(page_cursor/10)}')
#      46
#
# NameError: name 'city_cursor' is not defined

# %%
from collections import defaultdict
from IPython.display import clear_output

max_results_per_city = 4000 # Set this to a high-value (5000) to generate more results. 
# Crawling more results, will also take much longer. First test your code on a small number of results and then expand.

results = defaultdict(list)
status = defaultdict(list)

captcha=False

# while loop for repeating until certain amount of data is scraped - storing the city and result each time so we can continue from this point
# countries = [england, united_states, singapore]
# england = ['Chester' 'London', 'Manchester', 'Liverpool', 'Leeds', 'York', 'Bradford', 
#     'Milton+Keynes', 'Reading', 'Birmingham', 'Cardiff', 'Wolverhampton', 
#     'Edinburgh', 'Glasgow', 'Huddersfield', 'Crewe', 'Warwick', 'Oxford', 
#     'Cambridge', 'Bournemouth']

for city in set(['Denver', 'Seattle', 'Portland']):
#     pages = page_getter(city)
    for start in tqdm(range(0, max_results_per_city, 10)):
        url = f"http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={city}&start={start}"
        result = requests.get(url)
        status[city].append(result.status_code)
        soup = BeautifulSoup(result.text, 'html.parser')
        if 'hCaptcha' not in str(soup.prettify):
            for post in soup.find_all('div', attrs={'class':'jobsearch-SerpJobCard'}):
                results['title'].append(extract_job_title(post))
                results['company'].append(extract_company(post))
                results['location'].append(extract_location(post))
                results['country'].append('usa')
                results['salary'].append(extract_salary(post))
            time.sleep(20)
        else:
            print('Caught')
            city_cursor = city
            page_cursor = start
            captcha=True
            break
    if captcha==True:
        break
    time.sleep(20)


print(f'Stopped at {city_cursor}, page {int(page_cursor/10)}')
# Out:
#  69%|██████▉   | 275/400 [2:06:45<44:18, 21.27s/it]

# %%
# from collections import defaultdict
# from IPython.display import clear_output

# max_results_per_city = 3000 # Set this to a high-value (5000) to generate more results. 
# # Crawling more results, will also take much longer. First test your code on a small number of results and then expand.

# results = defaultdict(list)
# status = defaultdict(list)

# captcha=False

# for start in tqdm(range(0, max_results_per_city, 10)):
#     url = f"https://sg.indeed.com/jobs?q=Data+Scientist&start={start}"
#     result = requests.get(url)
#     status[city].append(result.status_code)
#     soup = BeautifulSoup(result.text, 'html.parser')
#     if 'hCaptcha' not in str(soup.prettify):
#         for post in soup.find_all('div', attrs={'class':'jobsearch-SerpJobCard'}):
#             results['title'].append(extract_job_title(post))
#             results['company'].append(extract_company(post))
#             results['location'].append(extract_location(post))
#             results['country'].append('singapore')
#             results['salary'].append(extract_salary(post))
#         time.sleep(25)
#     else:
#         print('Caught')
#         city_cursor = city
#         page_cursor = start
#         captcha=True
#         break
# if captcha==True:
#     break
# time.sleep(20)


# print(f'Stopped at {city_cursor}, page {int(page_cursor/10)}')
# Out:
# 100%|██████████| 300/300 [2:13:47<00:00, 26.76s/it]
#   File "<ipython-input-691-b6d6c9381a2c>", line 31
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
pages
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-444-554d1f4c9748> in <module>
# ----> 1 pages
#
# NameError: name 'pages' is not defined

# %%
results
# Out:
# defaultdict(list,
#             {'title': ['Data Scientist',
#               'Data Scientist',
#               'Data Science Intern',
#               'Data Science Intern',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist - R& Python',
#               'Junior Data Scientist',
#               'Associate Data Scientist',
#               'Data Scientist',
#               'VelocITy Data & AI Graduate Programme, UK',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Audience Measurement - Junior Data Scientist',
#               'Data Scientist',
#               'Data Scientist Internship',
#               'Product Data Scientist',
#               'Data Governance Associate Scientist',
#               'Data Scientist - Associate',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Science Intern',
#               'DATA SCIENTIST | VERV | LONDON OR SHEFFIELD',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Science Intern',
#               'Research Scientist',
#               'Data Scientist',
#               'Graduate Data Scientist - Insurance Consulting (Reigate or L...',
#               'Junior Data Scientist - London',
#               'DATA SCIENCE CONSULTANT LONDON',
#               'Senior Data Scientist - People Recommendations',
#               'Data and Analytics Strategy Consultant',
#               'Data Scientist',
#               'Data Scientist, Causal Inference',
#               'Senior Data Scientist, Personal Banking',
#               'Data Scientist - open to remote working',
#               'Data Scientist',
#               'Data Insight - Analytics Strategist',
#               'Data Science Internship',
#               'Customer Analytics Data Scientist Senior Associate',
#               'Senior Data Scientist - Badoo',
#               'Intern - Data Scientist',
#               'Junior Data Scientist/Analyst',
#               'Data Analytics Specialist',
#               'Fraud Data Scientist',
#               'Machine Learning Scientist - Data Science & AI',
#               'Data Scientist III (Meta Bidding)',
#               'PSG Associate Data Scientist',
#               'Sales Data Scientist',
#               'Machine Learning Scientist Intern',
#               'Intern - Machine Learning Engineer',
#               'Intern, AI Lab UK (Summer)',
#               'Analyst, Data Science (12 month Fixed-Term Contract)',
#               'Lead Data Scientist',
#               'Vice President – Data Science',
#               'Machine Learning Engineer, Risk & Abuse',
#               'Data Scientist',
#               'Machine Learning Engineer Internship',
#               'Data Scientist – Aerospace and Defence',
#               'Python Software Engineer - Cloud / Data Science',
#               'Higher Statistical Data Scientist - across the GSS',
#               'Healthcare Data Scientist',
#               'Data Scientist',
#               'Head of Data Science, Financial Crime',
#               'Data Scientist',
#               'Data Scientist, Product Analytics',
#               'Data Scientist',
#               'Machine Learning Engineer - Data Science & AI',
#               'Data Scientist, Product',
#               'Data Scientist',
#               'Junior Data Scientist',
#               'Data Scientist, Legal',
#               'Research Data Scientist',
#               'Senior Data Scientist - Marketing',
#               'MSc Data Science Online Tutor',
#               'Sales Data Scientist',
#               'Data Scientist, Product Analytics',
#               'Senior Data Scientist, Operations and Financial Crime',
#               'Data Science Internship',
#               'Data Scientist',
#               'Data Scientist (Tableau) – Remote',
#               'Senior Data Scientist',
#               'DATA SCIENTIST',
#               'Data Scientist – Aerospace and Defence',
#               'Data Scientist -Ranking & Recommendations',
#               'Data Scientist (Contract) - Experimentation',
#               'Data Scientist (Contract) - Simulation',
#               'Data Scientist (Contract) - Forecasting',
#               'Machine Learning Data Engineer',
#               'Data Scientist',
#               'Senior Statistical Data Scientist - across the GSS',
#               'Senior Teaching Fellow in Business Analytics and Data Scient...',
#               'Data Scientist',
#               'Head of Product - Applied AI/ML (Artificial Intelligence / M...',
#               'Data Scientist',
#               'MASTER DATA SCIENTIST',
#               'Senior Data Scientist',
#               'Data Services Analyst, Endeavor Analytics',
#               'Data Scientist (Contract) - Ecommerce',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Graduate Data Scientist - Insurance Consulting (Reigate or L...',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Sales Data Scientist',
#               'Data Scientist (m/w/d)',
#               'DATA SCIENCE TEAM LEAD - FINTECH',
#               'DATA SCIENCE CONSULTANT LONDON',
#               'Data Engineer/Scientist',
#               'Brand Sales Specialist - Data & AI',
#               'DATA SCIENTIST',
#               'Data Scientist (Contract) - Forecasting',
#               'Core Data Scientist/Engineer',
#               'Vice President – Data Science',
#               'Data Scientist',
#               'Lead Decision Data Scientist',
#               'Senior Data Scientist, Consumer Experience',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist (Contract) - Geospatial',
#               'Data Scientist - Predictive Analytics',
#               'Data Scientists - Consulting',
#               'Research Scientist',
#               'Data Scientist',
#               'Customer Facing Data Scientist',
#               'Data Scientist',
#               'Data Scientist – Independent Media Agency',
#               'Machine Learning Scientist - Data Science & AI',
#               'Data Scientist (Geospatial) - Contract',
#               'Data Scientist (Energy / Decarbonisation)',
#               'Data Scientist - Retail',
#               'Data Scientist',
#               'Data Scientist - Marketing Science',
#               'Analyst, Data Science (12 month Fixed-Term Contract)',
#               'Data Scientist - FTC - 3- Month Rolling Contract',
#               'Data Scientist, B2B Demand Generation',
#               'Principal Data Scientist',
#               'Snr. Data Scientist, Market Research',
#               'Senior Data Scientist',
#               'Data Scientist – 51594',
#               'Manager, Research Data Science',
#               'Head of E-Commerce Analytics',
#               'AI/ML Engineer',
#               'Data Scientist, Performance Marketing',
#               'Senior Data Scientist',
#               'Head of Data Science- Health',
#               'Data Scientist (Remote)',
#               'Risk Analyst - Quantitative Modelling & Analysis, RALC (SRS)',
#               'Data Scientist Director',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Data Scientist (Contract) - Statistics',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'NLP Data Scientist',
#               'Senior Data Scientist London',
#               'Data Scientist - Predictive Analytics',
#               'Manager, Data and Analytics- Capital Markets, Financial Serv...',
#               'Data Scientist – London',
#               'Data Scientist',
#               'Software Engineer - Machine Learning',
#               'Senior Data Scientist London',
#               'Advisor, Data science and analytics',
#               'Principal Data Scientist',
#               'Global Markets Division - SFL Strats - Associate - London',
#               'Data Scientist – 51594',
#               'Applied Scientist - Deep Learning',
#               'Senior Data Scientist',
#               'Senior Supply Chain Analytics Consultant',
#               'Data Analyst - Rare Diseases',
#               'Data Scientist',
#               'Data & AI Business Analyst',
#               'Data Scientist',
#               'Data Scientist (Multiple Seniorities)',
#               'Advisor, Data science and analytics',
#               'Analytics Engineer',
#               'Data Scientist',
#               'Head of Data Science',
#               'Python Software Engineer - Cloud / Data Science',
#               'Data Science Consultant (FTC)',
#               'Data Scientist',
#               'Artificial Intelligence',
#               'Data Scientist',
#               'Senior Data Scientist (m/f/d)',
#               'Lead Data Scientist',
#               'AI/ML Engineer',
#               'Machine Learning Engineer',
#               'Data Scientist Python - Hedge Fund',
#               'AI & ML DevOps Engineer - Contract',
#               'Data Scientist',
#               'Senior Machine Learning Engineer',
#               'Senior Data Scientist',
#               'Machine Learning Engineer',
#               'Data Science Lead',
#               'Machine Learning Engineer (Remote)',
#               'Lead/ Senior Data Scientist',
#               'Data Analyst, Renewable Energy',
#               'Senior Supply Chain Analytics Consultant',
#               'Data Scientist - Senior Consultant',
#               'Sr. Manager, Data Science',
#               'AI/ML Engineer',
#               'Data Scientist – London',
#               'Data Scientist – Independent Media Agency',
#               'Decision Scientist',
#               'Data Science Analyst, Ascential Marketing Division',
#               'Senior Data Scientist London',
#               'NLP Data Scientist (Mid-Senior Level)',
#               'Python Developer - AI SAAS',
#               'Data Analyst - Rare Diseases',
#               'Advisor, Data science and analytics',
#               'Data Scientist',
#               'Manager, Advanced Data Insight Analytics',
#               'Staff Deep Learning Engineer',
#               'Data Scientist',
#               'Lead Data Scientist',
#               'Data Scientist – 51594',
#               'Data Science Consultant',
#               'Staff Deep Learning Engineer',
#               'Data Scientist',
#               'Lead Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Machine Learning Scientist',
#               'Product Data Analyst',
#               'DATA SCIENTIST',
#               'Head of Data Science',
#               'Specialist, Data Science',
#               'NLP Data Scientist',
#               'Big Data Engineer - Hadoop, Spark, AWS',
#               'Data Science Analyst Fixed Term Contract London',
#               'Statistician',
#               'Natural Language Processing (NLP)',
#               'Part-time Data Scientist',
#               'Data Scientist',
#               'Head of E-Commerce Analytics',
#               'Data Science Consultant',
#               'Big Data Engineer - Hadoop, Spark, AWS',
#               'Data Science Analyst Fixed Term Contract London',
#               'Head of Data Science',
#               'Data Science and Analytics Consultant/Researcher',
#               'AI Solutions Manager, Life Science',
#               'AI Advisory / Data Science Advisory, Senior Manager',
#               'Senior Data Scientist',
#               'Machine Learning Engineer (Contract) - Outside IR35',
#               'Biological Data Science Specialist',
#               'Machine Learning Researcher',
#               'Data Scientist',
#               'Senior Applied Scientist - Traffic & Pricing Platform (w/d/m...',
#               'Sr Data Scientist',
#               'Manager, Data and Analytics- Capital Markets, Financial Serv...',
#               'Machine Learning Engineer - Discover',
#               'Software Engineer, Machine Learning',
#               'Data Science Consultant',
#               'Staff Deep Learning Engineer',
#               'Management Consultant - Supply Chain Analytics',
#               'Machine Learning Engineer',
#               'Advanced Data Insight Analyst III (Marketing Analytics)',
#               'C# Developer: NLP Team',
#               'NLP Data Scientist',
#               'Data Scientist',
#               'Data Science Associate Consultant',
#               'Part Time Faculty for Business Analytics',
#               'Principal Data Scientist',
#               'Senior Audio Machine Learning Engineer',
#               'Marketing Data Scientist',
#               'Data Scientist / AI Engineer',
#               'Staff Machine Learning Research Engineer - Cortex Recommende...',
#               'Senior Data Scientist',
#               'Strategic Consultant - Data Science & Analytics',
#               'Data Science Manager, London',
#               'Machine Learning Engineer',
#               'Data Scientist',
#               'Data Scientist Python - Hedge Fund',
#               'Senior Data Scientist, Insights & Innovation, UK',
#               'Pricing Transformation Big Data Analyst',
#               'Data Scientist, B2B Marketing',
#               'Data Scientist',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Data Scientist',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Machine Learning Platform Engineer',
#               'Junior data science engineer',
#               'Data Science Consultant',
#               'Analyst Healthcare Analytics homebased',
#               'Visual Analytics Consultant',
#               'Data Scientist',
#               'AI Engineer',
#               'Natural Language Processing Engineers',
#               'Head of Data Science',
#               'Data Engineer – Data Science',
#               'Pricing Data Scientist',
#               'Data Scientist - Health Outcomes',
#               'Market Director - Forensic Data Analytics - London',
#               'Data Scientist - Python Developer',
#               'Data Science Lead',
#               'Machine Learning Engineer (Remote)',
#               'Lead/ Senior Data Scientist',
#               'Data Analyst, Renewable Energy',
#               'Senior Data Scientist / ML Engineer',
#               'Data Scientist - Senior Consultant',
#               'Sr. Manager, Data Science',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Senior Strategic Consultant - Data Science & Analytics',
#               'Senior Data Scientist - Global participation',
#               'Senior Data Scientist – London',
#               'Data Scientist',
#               'Data Scientist - NLP Specialist',
#               'BIG DATA ARCHITECT',
#               'Principal Data Scientist, Reinforcement Learning',
#               'Data Scientist (Contract) - Insights',
#               'Principal Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist/ Senior Data Scientist',
#               'Lead/ Senior Data Scientist',
#               'Machine Learning Lead',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Senior Data Scientist, Insights & Innovation, UK',
#               'Principal Applied Scientist',
#               'Senior Applied Scientist - Information Retrieval and Natural...',
#               'Vice President, Advanced Analytics & Prototyping, SpendingPu...',
#               'Data Scientists - Consulting',
#               'Data Analyst, Renewable Energy',
#               'Data Scientist (Geospatial) - Contract',
#               'Data Scientist (NLP) - Inside IR35',
#               'Data Scientist',
#               'Senior Game Data Scientist - Racing',
#               'Head of Data Science',
#               'Engineering Manager - Machine Learning - Health',
#               'AI Architect – London',
#               'Data Lab Architect',
#               'BI Data Manager - Analytics',
#               'Data Scientist',
#               'Data Scientists - Consulting',
#               'Machine Learning Engineer',
#               'Analytics Engineer – Qlik',
#               'Machine Learning Engineer',
#               'Senior Data Scientist - Forecasting',
#               'Senior Data Scientist / Operational Researcher',
#               'AI Architect – London',
#               'Senior Engineer – Machine Learning and Computer Vision',
#               'Applied Scientist - Automated Reasoning',
#               'Senior Data Scientist, Product',
#               'Quantitative Researcher (Data Science/Machine Learning/Mathe...',
#               'Data Science Director',
#               'Lecturer in Climate Physics, Data Science in Climate Energy,...',
#               'Data Scientist',
#               'Senior Applied Scientist - Traffic & Pricing Platform (w/d/m...',
#               'Analytics Engineer – Qlik',
#               'Staff Product Manager - Machine Learning Platform',
#               'LEAD DATA ENGINEER – PYTHON, SQL – DATA SCIENCE – FINANCIAL...',
#               'CIB Investment Bank - Applied AI & Machine Learning - Execut...',
#               'Data Science Leader',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Data Scientist',
#               'Principal Data Scientist - Remote, UK',
#               'Machine Learning Engineer - Kubrick',
#               'Data Scientist',
#               'Data Scientist',
#               'Senior Data Scientist - Badoo',
#               'Senior Data Scientist, Product Analytics',
#               'Machine Learning Scientist Intern',
#               'Computer Vision Deep Learning Engineer',
#               'Senior Data Scientist',
#               'Capital, Control and Operations Big Data Architect',
#               'Natural Language Processing (NLP)',
#               'Applied Scientist - Information Retrieval and Natural Langua...',
#               'Quantitative Researcher (Data Science/Machine Learning/Mathe...',
#               'Database & Data Science Developer',
#               'Data Scientist',
#               'Data Scientist',
#               'Senior Data Architect / Data Scientist - 100% Remote across...',
#               'Senior Data Scientist - 8 MONTH FTC',
#               'Principal Consultant - Analytics Consulting',
#               'Management Consultant – Digital Marketing Analytics',
#               'Lead Data Scientist',
#               'Big Data and Data Science Platforms - Tech lead - FS',
#               'Director, Artificial Intelligence Consulting',
#               'Digital Web Analytics Manager',
#               'Senior Specialist, Data Science',
#               'Associate Director, Digital and Analytics Operations - ICR R...',
#               'Senior Data Scientist',
#               'Pre-Sales Solution Engineer, BI & Analytics',
#               'Analytics Consultant',
#               'Data & Analytics Senior Manager, Digital Pre-school Centre o...',
#               'Research Data Scientist',
#               'Legal Technologist - Machine Learning & Artificial Intellige...',
#               'Head of Data Science',
#               'Pre-Sales Solution Engineer, BI & Analytics',
#               'Head of Data Science',
#               'LEAD DATA ENGINEER – PYTHON, SQL – DATA SCIENCE – FINANCIAL...',
#               'Business Intelligence Engineer - Customer behavior & marketi...',
#               'Lead Data Scientist',
#               'AI Engineer',
#               'Machine Learning Engineer',
#               'Programme Management, Data Science Lead',
#               'Sr Machine Learning Engineer',
#               'Associate Educator, Data Scientist',
#               'Head of Data Science',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Machine Learning Researcher',
#               'Transaction Monitoring Modelling & Analytics',
#               'Algorithm & Software Developer (Machine Learning, Computer V...',
#               'Data Scientist - Machine Learning (Python/SQL)',
#               'Machine Learning Engineer',
#               'Data Scientist Director',
#               'Project Manager, Data & Analytics',
#               'Machine Learning Research Engineer',
#               'Digital Audit Advanced Analytics Senior Associate',
#               'Software Engineer - Machine Learning',
#               'Retail Senior Data Scientist / Retail Data Science Manager',
#               'Machine Learning Team Lead',
#               'Educator, Data Scientist',
#               'Head of Data Science - London - (Cutting Edge NLP!!)',
#               'Senior Data Scientist/ Machine Learning Developer',
#               'Senior Applied Scientist - Information Retrieval and Natural...',
#               'Research Scientist, Natural Language Processing (PhD)',
#               'Senior Data Scientist - UK',
#               'Principal Data Science Consultant',
#               'Machine learning Software Engineer - Senior Associate',
#               'Data Scientist | Python | NLP | London | Contract',
#               'Machine Learning Lead',
#               'AI-Quant - Junior',
#               'Head of Data Science - London - (Cutting Edge NLP!!)',
#               'Senior Data Scientist/ Machine Learning Developer',
#               'Lead Data Scientist',
#               'Data Scientist',
#               'Senior Data Science Engineer',
#               'Senior Data Scientist',
#               'Head of Data Science',
#               'Data Scientist',
#               'Data Scientist (Multiple Seniorities)',
#               'Senior Data Science Engineer',
#               'Machine Learning Engineer',
#               'Data Science Manager - EMEA',
#               'Full Cycle Data Scientist - FinTech',
#               'Machine Learning Engineer',
#               'Machine Learning Engineer',
#               'Analytics Strategy Manager',
#               'Research Data Scientist',
#               'Computer Vision Deep Learning Engineer',
#               'Deep Learning Engineer',
#               'Machine Learning Research Scientist',
#               'Senior Applied Scientist',
#               'Data Scientist - Cancer',
#               'Quantitative Researcher in Natural Language Processing (NLP)',
#               'VP Customer Success @ Leading Machine-Learning SaaS Platform',
#               'Python Developer SQL Machine Learning AWS',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Faculty Data Science & Data Engineering Fellowship (Oct 2021...',
#               'Machine Learning Engineer - Genomic Data',
#               'Technical Product Manager - Data AI Machine Learning',
#               'Analytics Cloud Specialist, EMEA',
#               'NLP Data Scientist',
#               'Product Manager – AI & Machine Learning',
#               'Account Manager @ Machine-Learning Startup',
#               'Product Manager & Data Scientist',
#               'Senior Data Scientist | Search & Rank',
#               'Financial Quant/Data Science - Fintech - London or Paris',
#               'Senior Manager, Customer Analytics',
#               'Data Scientist',
#               'Machine Learning Engineer (Contract) - Outside IR35',
#               'AI Advisory / Data Science Advisory, Senior Manager',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Analytics Strategy Manager',
#               'Digital Web Analytics Manager',
#               'Big Data Engineer',
#               'Analytics Engineer – Qlik',
#               'AI Architect – London',
#               'Machine Learning Research Engineer',
#               'Data Scientist',
#               'Machine Learning Engineer',
#               'Associate Director, Digital and Analytics Operations - ICR R...',
#               'Senior Data Scientist',
#               'Pre-Sales Solution Engineer, BI & Analytics',
#               'Data & Analytics Senior Manager, Digital Pre-school Centre o...',
#               'Senior Data Scientist',
#               'Director – Analytics & AI',
#               'Principal Machine Learning Engineer',
#               'Senior Business Analyst/Data architect',
#               'Big Data Solutions Architect – London',
#               'Financial Crime Analytics Manager',
#               'Site Reliability Engineer - Machine Learning',
#               'Machine Learning Engineer',
#               'Agile Project Manager - Data Analytics',
#               'Data Scientist',
#               'PhD Student, London (AI)',
#               'Data Scientist - Advanced Analytics & Insight',
#               'Lead AI/ML Engineer',
#               'Data Science Team Leader - Robotics',
#               'Lead Data Scientist',
#               'Account Manager, Data Science and Tool Development',
#               'ARTIFICIAL INTELLIGENCE SPECIALIST',
#               'Senior Analytics Translator',
#               'Senior Data Scientist',
#               'AI Success Director',
#               'Head of Data Science - eCommerce',
#               'Lead Data Scientist',
#               'Software Engineer, Machine Learning',
#               'AI/ML Engineer - Production',
#               'Machine Learning Engineer',
#               'Senior Software Engineer (Data Science)',
#               'PSG Business Intelligence & Data Science Manager',
#               'Principal Data Scientist',
#               'Senior Analytics Translator',
#               'Machine Learning Engineer - Golf Start-Up - Python AWS ML Pr...',
#               'Senior Data Scientist',
#               'AI Success Director',
#               'Head of Data Science - eCommerce',
#               'Data Scientist – Insurance',
#               'Lead Data Scientist',
#               'Data Scientist - London',
#               'Data Scientist (Product)',
#               'Software Engineer, Machine Learning',
#               'AI/ML Engineer - Production',
#               'Principal Machine Learning Scientist - Patient Data Analytic...',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Data Scientist',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Data Scientist - Manager - UKI Assurance - Forensic Data Ana...',
#               'Data Scientist (Geospatial) - Contract',
#               'Senior Game Data Scientist - Racing',
#               'Data Scientist',
#               'Engineering Manager - Machine Learning - Health',
#               'Head of Data Science',
#               'Data Lab Architect',
#               'Data Scientists - Consulting',
#               'Machine Learning Engineer',
#               'Senior Data Scientist - Forecasting',
#               'Database & Data Science Developer',
#               'Market Director - Forensic Data Analytics - London',
#               'Data Scientist - Python Developer',
#               'Apple Media Products (AMP)- Big Data Engineer - Core Marketi...',
#               'Software Engineer, Machine Learning & Program Analysis',
#               'Head Of Data & Analytics',
#               'Data Scientist',
#               'Senior Software Engineer, AI/ML Production',
#               'Partner Engineer - Network Analytics',
#               'Senior Machine Learning Research Engineer',
#               'Computer Vision Engineer, Deep Learning',
#               'Junior Data Science Consultant',
#               'Senior Data Scientist',
#               'Deep Learning Scientist',
#               'Professor in Computer Vision and Machine Learning',
#               'Data Analytics Lead',
#               'Data Scientist Python PhD',
#               'Data Science Lecturer',
#               'Principal Machine Learning Engineer',
#               'Senior Consultant, Medallia Strategy Analytics',
#               'Deep Learning Engineer',
#               'Principal Machine Learning Engineer REMOTE',
#               'Senior Software Engineer (Data Science)',
#               'Senior Data Scientist',
#               'Audience Measurement - Data Science Product Manager',
#               'Senior Statistician, Data Science',
#               'Technical Product Manager (Machine Learning)',
#               'Senior Data Scientist',
#               'Computer Vision Machine Learning Engineer',
#               'Machine Learning Research Engineer',
#               'Pre-sales Solutions Architect - Data & AI',
#               'Data Scientist',
#               'Senior NLP Researcher',
#               'Software Engineer - Data/Machine Learning - £550/650pd',
#               'Financial Crime Analytics Manager',
#               'Audio Machine Learning Data Engineer',
#               'BI Data Manager - Analytics',
#               'Professor in Computer Vision and Machine Learning',
#               'Deep Learning Engineer',
#               'Big Data Engineer - Hadoop, Spark, Cloud',
#               'Principal Scientist - Patient Data Analytics',
#               'AI Success Director',
#               'Adobe Analytics Lead',
#               'Data Scientist',
#               'Analytics Manager London',
#               'Data Science Content Developer',
#               'Algorithm & Software Developer (Machine Learning, Computer V...',
#               'Machine Learning Engineer (Two way recommender systems)',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Data Scientist',
#               'FINANCE ANALYTICS MANAGER, PROPERTY & CASUALTY',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Legal Technologist - Machine Learning & Artificial Intellige...',
#               'Senior AI/ML Engineer - Sequence Learning',
#               'Python Engineer Machine Learning SQL',
#               'Digital Analytics Manager London, United Kingdom Consumer',
#               'Senior Data Scientist',
#               'Statistical Programmer I (SAS or R) – Real World Evidence (o...',
#               'Quantitative Researcher in Natural Language Processing (NLP)',
#               'VP Customer Success @ Leading Machine-Learning SaaS Platform',
#               'SENIOR DATA SCIENTIST',
#               'Python Developer SQL Machine Learning AWS',
#               'Senior Data Scientist',
#               'Senior Applied Research Scientist, NLP',
#               'Senior Machine Learning Engineer',
#               'Machine Learning Engineer',
#               'Digital Analytics Manager',
#               'Director of Applied Data Science',
#               'Senior Machine Learning Research Engineer',
#               'Director, Data Science',
#               'Senior Biostatistician (FSP) Home Based',
#               'Apple Media Products (AMP)- Big Data Engineer - Core Marketi...',
#               'Data Scientist',
#               'Data Scientist',
#               'Consulting Project Manager Analytics & Clinical Services',
#               'Director - Analytics & AI',
#               'Data Science Team Leader - Robotics',
#               'Principal Data Science Consultant',
#               'Machine Learning (Contract) - Outside IR35',
#               'Machine Learning Research Engineer',
#               'Staff Machine Learning Engineer',
#               'Machine Learning Engineer III',
#               'Senior Bioinformatics Data Scientist',
#               'Principal Machine Learning Engineer',
#               'Senior Data Science Engineer',
#               'Data Scientist',
#               'Product Manager (Data Science)',
#               'Big Data Lead',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Data Science – Recruitment Consultant – City of London',
#               'NLP Developer/ML Engineer',
#               'FINANCE ANALYTICS MANAGER, PROPERTY & CASUALTY',
#               'Lead Data Engineer - AI Consultancy - London',
#               'Lead NLP Data Scientist',
#               'Senior Consultant, Advanced Analytics (Remote)',
#               'Head of Data Science',
#               'Machine Learning Engineer',
#               'Real World Data Senior Biostatistician',
#               'Data Science Consultant - Software Product',
#               'Data Scientist',
#               'Senior Research Data Scientist',
#               'Machine Learning Developer',
#               'Senior Manager Data and Analytics',
#               'Data Scientist/ Senior Data Scientist',
#               'Lead Machine Learning Teacher',
#               'Genomics Data Scientist',
#               'Cancer Genomics Data Scientist',
#               'Big Data Engineering Lead',
#               'Head of Data Science',
#               'Data Scientist - Government',
#               'AI-Quant - Intermediate',
#               'Machine Learning Software Engineer',
#               'Machine Learning Engineer - Trading',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - ML/NLP',
#               'NLP Data Scientist',
#               'Lead Data Science Consultant',
#               'Data Scientist',
#               'Senior Advisor, Data science and Analytics',
#               'Senior Machine Learning Engineer',
#               'Senior Data Scientist - Forecasting',
#               'Software Engineer (AI / ML)',
#               'Robotics Research Engineer - Machine Learning',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'NLP Data Scientist',
#               'Big Data DevOps Engineer',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Senior Machine Learning Engineer - Leading Data/ AI Consulta...',
#               'Senior Product Manager (Data Science/ AI)',
#               'AI Success Director (Spanish Language Requirements)',
#               'Product Manager (Data Science)',
#               'Senior Analytics Engineer- DBT',
#               'Senior Machine Learning Engineer',
#               'Principal Biostatistician',
#               'Software Engineer, AR Machine Learning',
#               'Senior Data Scientist',
#               'Customer-Facing Data Scientists - London',
#               'Senior Data Scientist',
#               '1774- Sr. Director, Analytics and Modeling',
#               'Senior Software Engineer (Python), AI/Machine Learning - Lon...',
#               'Data Scientist (Growth Tribe)',
#               'Director, Patient Services Analytics and Insights',
#               'Senior Data Scientist',
#               '1774- Sr. Director, Analytics and Modeling',
#               'Senior Software Engineer (Python), AI/Machine Learning - Lon...',
#               'Data Scientist (Growth Tribe)',
#               'Director, Patient Services Analytics and Insights',
#               'Machine Learning/Computer Vision Scientist (Home W',
#               'Digital Analytics Manager',
#               'Pre-Sales Solution Engineer, BI & Analytics, Tableau',
#               'Data Science Manager',
#               'Lead Machine Learning Scientist',
#               'NLP Data Scientist',
#               'Applied Machine Learning Scientist',
#               'Senior Data Science Consultant',
#               'ARTIFICIAL INTELLIGENCE & ALGORITHM PRO',
#               'Senior Machine Learning Engineer',
#               'Senior Bioinformatics Data Scientist',
#               'Polyglot Engineer (AI Start-Up) - Python/ Golang/ Javascript',
#               'Performance Analytics Manager',
#               'Manager, Global Analytics Platform',
#               'C++ Developer - Risk, Machine Learning - London',
#               'Machine Learning Engineer; Computer Vision, Data S',
#               'Lead Engineer - Python - Machine Learning',
#               'Senior Lead Analyst - Analytics Technology',
#               'Lead Data Scientist',
#               'Principal Statistician',
#               'Senior Machine Learning Scientist - DeepTech Startup (AgriTe...',
#               'Senior Machine Learning Engineer',
#               'Principal Data Scientist (Supply)',
#               'Data Scientist',
#               'Product Analytics Manager',
#               'Principal Biostatistician (FSP) Home Based',
#               'MACHINE LEARNING SPECIALIST',
#               'Quantitative Financial Modeller – Balance Sheet & Analytics',
#               'Data Analytics Manager – Telecommunications',
#               'Senior AI/ML Engineer',
#               'Senior Biostatistician (FSP) Home Based',
#               'Technical Coach: Data Science',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Machine Learning Engineer',
#               'Senior Business Intelligence Consultant – CRM Analytics',
#               'Head of Analytics',
#               'Senior Machine Learning Engineer',
#               'Recruitment Consultant - Data Science',
#               'Lead Data Scientist / R&D Engineer',
#               'Senior Analyst/Developer, Pricing Analytics & Models (PAM) &...',
#               'Product Manager | AI',
#               'Senior Data Science Engineer',
#               'Senior ML Engineer',
#               'Technical BA - Analytics & Automation',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior Software Engineer - Machine Learning',
#               'Machine Learning Engineer',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Software Engineer (AI / ML)',
#               'Senior Product Manager, Database Capabilities (Graph & Time...',
#               'Senior Statistician',
#               'Data Analytics Manager – Telecommunications',
#               'Director, Patient Services Analytics and Insights',
#               'Senior Machine Learning Engineer',
#               'Product Manager | AI',
#               'Senior Data Science Engineer',
#               'Senior ML Engineer',
#               'Machine Learning Ops Engineer',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior ML Engineer (contract)',
#               'Data Scientist',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Principal Data Scientist - Remote, UK',
#               'Data Scientist',
#               'Senior Machine Learning Scientist',
#               'Senior Data Scientist',
#               'Business Analyst - Analytics',
#               'Analytics Cloud Specialist, EMEA',
#               'BIG DATA ARCHITECT',
#               'Principal Consultant - Analytics Consulting',
#               'Solution Architect - Technical Presales (Big Data, Analytics...',
#               'Pre-sales Solutions Architect - Data & AI - Retail or CPG',
#               'Machine Learning Engineer',
#               'Product Analytics Manager',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Database & Data Science Developer',
#               'Data Scientist',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Software Engineer - Machine Learning',
#               'Senior Machine Learning Engineer',
#               'Senior Linux/DevOps Engineer with focus on Big Data',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Senior Product Manager, Database Capabilities (Graph & Time...',
#               'Robotics Research Engineer - Machine Learning',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Econometric Analyst - Machine Learning',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Technical BA - Analytics & Automation',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Big Data DevOps Engineer',
#               'Senior Technical Product Manager, AI & Machine Learning, Rea...',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Data Scientist',
#               'Data Scientist',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Apple Media Products (AMP)- Big Data Engineer - Core Marketi...',
#               'Data Scientist',
#               'Data Scientist',
#               'Partner Engineer - Network Analytics',
#               'Senior Data Scientist',
#               'Data Engineer – Specialty Analytics',
#               'Data Science Manager',
#               'Analytics Consultant',
#               'Market Director - Forensic Data Analytics - London',
#               'Data Scientist - Python Developer',
#               'Machine Learning Platform Engineer',
#               'Principle Data Scientist',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'Senior Software Engineer (Data Science)',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Research Data Scientist',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Machine Learning Engineer',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Linux/DevOps Engineer with focus on Big Data',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Technical BA - Analytics & Automation',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'NLP Data Scientist',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Senior Product Manager, Database Capabilities (Graph & Time...',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'NLP Data Scientist',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Machine Learning Engineer',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Linux/DevOps Engineer with focus on Big Data',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
# ...
#               nan,
#               nan,
#               '£59688 - £67767 a year',
#               '£40000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               '£85000 - £95000 a year',
#               nan,
#               nan,
#               '£53000 a year',
#               nan,
#               '£40000 - £50000 a year',
#               nan,
#               '£32000 a year',
#               '£35000 - £45000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £80000 a year',
#               '£80000 - £110000 a year',
#               '£60000 - £65000 a year',
#               nan,
#               nan,
#               '£95000 a year',
#               '£70000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£40000 - £50000 a year',
#               nan,
#               '£50000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£85000 - £95000 a year',
#               nan,
#               '£80000 - £100000 a year',
#               nan,
#               '£390 - £425 a day',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£55000 - £75000 a year',
#               nan,
#               '£70000 - £100000 a year',
#               '£32000 a year',
#               '£90000 - £110000 a year',
#               nan,
#               '£34000 - £38000 a year',
#               nan,
#               nan,
#               '£68139 - £75710 a year',
#               nan,
#               nan,
#               '£120000 - £130000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£500 - £600 a day',
#               '£75000 - £100000 a year',
#               nan,
#               '£120000 - £130000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£65000 - £70000 a year',
#               nan,
#               '£40000 - £55000 a year',
#               '£40000 - £110000 a year',
#               nan,
#               '£70000 - £90000 a year',
#               nan,
#               '£80000 - £120000 a year',
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               '£40000 - £65000 a year',
#               nan,
#               '£60000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£80000 - £95000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£75000 a year',
#               '£500 - £550 a day',
#               '£110000 - £130000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£75000 - £95000 a year',
#               nan,
#               nan,
#               '£32000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£90000 a year',
#               '£65000 - £75000 a year',
#               nan,
#               nan,
#               '£65000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£80000 - £95000 a year',
#               nan,
#               '£60000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               '£40000 - £45000 a year',
#               '£70000 a year',
#               nan,
#               '£50000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£35000 - £45000 a year',
#               '£53000 a year',
#               nan,
#               '£32000 a year',
#               '£40000 - £50000 a year',
#               nan,
#               nan,
#               '£450 - £500 a day',
#               nan,
#               nan,
#               nan,
#               '£110000 - £120000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£350 - £400 a day',
#               nan,
#               nan,
#               nan,
#               '£50000 - £62000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£40000 - £50000 a year',
#               nan,
#               '£80000 - £85000 a year',
#               nan,
#               nan,
#               '£65000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               '£70000 - £100000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£65000 a year',
#               nan,
#               '£55000 - £75000 a year',
#               '£60000 - £70000 a year',
#               '£70000 a year',
#               nan,
#               nan,
#               nan,
#               '£550 - £650 a day',
#               '£65000 - £75000 a year',
#               nan,
#               '£570 a day',
#               nan,
#               '£60000 a year',
#               '£90000 - £120000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£75000 - £85000 a year',
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£55000 - £65000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               '£60000 - £80000 a year',
#               nan,
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£550 - £650 a day',
#               '£70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £100000 a year',
#               '£60000 - £90000 a year',
#               '£80000 - £95000 a year',
#               nan,
#               nan,
#               '£37000 a year',
#               nan,
#               nan,
#               nan,
#               '£75000 - £95000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£55000 - £75000 a year',
#               '£50000 - £60000 a year',
#               '£60000 a year',
#               nan,
#               '£50000 - £100000 a year',
#               '£85000 - £100000 a year',
#               nan,
#               nan,
#               '£100000 a year',
#               nan,
#               nan,
#               nan,
#               '£40000 - £50000 a year',
#               '£65000 - £75000 a year',
#               '£85000 - £100000 a year',
#               nan,
#               nan,
#               '£85000 - £100000 a year',
#               nan,
#               nan,
#               '£60000 - £80000 a year',
#               '£65000 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               nan,
#               '£60000 - £90000 a year',
#               '£70000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               '£40000 - £70000 a year',
#               nan,
#               nan,
#               '£70000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £90000 a year',
#               nan,
#               nan,
#               '£35000 - £40000 a year',
#               '£50000 - £60000 a year',
#               nan,
#               '£60000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £86000 a year',
#               '£35000 - £45000 a year',
#               nan,
#               '£90000 a year',
#               '£30000 - £55000 a year',
#               '£75000 - £95000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               '£65000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £70000 a year',
#               nan,
#               '£40000 - £45000 a year',
#               nan,
#               nan,
#               '£25000 - £35000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £45000 a year',
#               '£53000 a year',
#               nan,
#               '£32000 a year',
#               nan,
#               '£40000 - £50000 a year',
#               '£100000 - £120000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£28000 - £35000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£35000 - £45000 a year',
#               nan,
#               nan,
#               '£53000 a year',
#               '£40000 - £50000 a year',
#               '£32000 a year',
#               nan,
#               nan,
#               nan,
#               '£45000 a year',
#               '£50000 - £55000 a year',
#               nan,
#               '£85000 - £100000 a year',
#               '£60000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               '£350 - £400 a day',
#               '£40000 - £65000 a year',
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               '£50000 - £55000 a year',
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               ...]})

# %%
pd.DataFrame(results).shape
# Out:
# (10690, 5)

# %%
len(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-71d22cb8b1cf> in <module>
# ----> 1 len(cities)
#
# NameError: name 'cities' is not defined

# %%
# cities = ['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Seattle', 
#     'Los+Angeles', 'Philadelphia', 'Atlanta', 'Dallas', 'Pittsburgh', 
#     'Portland', 'Phoenix', 'Denver', 'Houston', 'Miami']

# from collections import defaultdict
# from IPython.display import clear_output

# max_results_per_city = 400 # Set this to a high-value (5000) to generate more results. 
# # Crawling more results, will also take much longer. First test your code on a small number of results and then expand.

# results = defaultdict(list)
# status = defaultdict(list)

# %%
# def scraper(cities, city_tracker, cursor):
#     captcha = False
#     results = defaultdict(list)
#     for i in range(city_tracker, len(cities)):
#         print(f'Scraping for {cities[i]}')
#         for start in tqdm(range(cursor, max_results_per_city, 10)):
#             cursor=0
#             url = f"http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={city}&start={start}"
#             result = requests.get(url)
#             soup = BeautifulSoup(result.text, 'html.parser')
#             if 'hCaptcha' not in str(soup.prettify):
#                 for post in soup.find_all('div', attrs={'class':'jobsearch-SerpJobCard'}):
#                     results['title'].append(extract_job_title(post))
#                     results['company'].append(extract_company(post))
#                     results['location'].append(extract_location(post))
#                     results['salary'].append(extract_salary(post))
#                 time.sleep(3)
#             else:
#                 print('caught')
#                 city_cursor = city
#                 page_cursor = start
#                 captcha = True
#                 break
#         if captcha == True:
#             break
#         time.sleep(15)
#     return results, city_cursor, page_cursor

# %%
# #intialise page and city trackers
# max_results_per_city = 300
# page = 0
# city = 0
# page = 0
# first_set = True
# while (page < max_results_per_city) and (city != len(cities)):
#     results, city, page = scraper(cities, city, page)
#     if first_set==True:
#         results_main = results
#     else:
#         results_main.update(results)
#     time.sleep(120)

# %%
results
# Out:
# defaultdict(list,
#             {'title': ['Data Scientist',
#               'Data Scientist',
#               'Data Science Intern',
#               'Data Science Intern',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist - R& Python',
#               'Junior Data Scientist',
#               'Associate Data Scientist',
#               'Data Scientist',
#               'VelocITy Data & AI Graduate Programme, UK',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Audience Measurement - Junior Data Scientist',
#               'Data Scientist',
#               'Data Scientist Internship',
#               'Product Data Scientist',
#               'Data Governance Associate Scientist',
#               'Data Scientist - Associate',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Science Intern',
#               'DATA SCIENTIST | VERV | LONDON OR SHEFFIELD',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Science Intern',
#               'Research Scientist',
#               'Data Scientist',
#               'Graduate Data Scientist - Insurance Consulting (Reigate or L...',
#               'Junior Data Scientist - London',
#               'DATA SCIENCE CONSULTANT LONDON',
#               'Senior Data Scientist - People Recommendations',
#               'Data and Analytics Strategy Consultant',
#               'Data Scientist',
#               'Data Scientist, Causal Inference',
#               'Senior Data Scientist, Personal Banking',
#               'Data Scientist - open to remote working',
#               'Data Scientist',
#               'Data Insight - Analytics Strategist',
#               'Data Science Internship',
#               'Customer Analytics Data Scientist Senior Associate',
#               'Senior Data Scientist - Badoo',
#               'Intern - Data Scientist',
#               'Junior Data Scientist/Analyst',
#               'Data Analytics Specialist',
#               'Fraud Data Scientist',
#               'Machine Learning Scientist - Data Science & AI',
#               'Data Scientist III (Meta Bidding)',
#               'PSG Associate Data Scientist',
#               'Sales Data Scientist',
#               'Machine Learning Scientist Intern',
#               'Intern - Machine Learning Engineer',
#               'Intern, AI Lab UK (Summer)',
#               'Analyst, Data Science (12 month Fixed-Term Contract)',
#               'Lead Data Scientist',
#               'Vice President – Data Science',
#               'Machine Learning Engineer, Risk & Abuse',
#               'Data Scientist',
#               'Machine Learning Engineer Internship',
#               'Data Scientist – Aerospace and Defence',
#               'Python Software Engineer - Cloud / Data Science',
#               'Higher Statistical Data Scientist - across the GSS',
#               'Healthcare Data Scientist',
#               'Data Scientist',
#               'Head of Data Science, Financial Crime',
#               'Data Scientist',
#               'Data Scientist, Product Analytics',
#               'Data Scientist',
#               'Machine Learning Engineer - Data Science & AI',
#               'Data Scientist, Product',
#               'Data Scientist',
#               'Junior Data Scientist',
#               'Data Scientist, Legal',
#               'Research Data Scientist',
#               'Senior Data Scientist - Marketing',
#               'MSc Data Science Online Tutor',
#               'Sales Data Scientist',
#               'Data Scientist, Product Analytics',
#               'Senior Data Scientist, Operations and Financial Crime',
#               'Data Science Internship',
#               'Data Scientist',
#               'Data Scientist (Tableau) – Remote',
#               'Senior Data Scientist',
#               'DATA SCIENTIST',
#               'Data Scientist – Aerospace and Defence',
#               'Data Scientist -Ranking & Recommendations',
#               'Data Scientist (Contract) - Experimentation',
#               'Data Scientist (Contract) - Simulation',
#               'Data Scientist (Contract) - Forecasting',
#               'Machine Learning Data Engineer',
#               'Data Scientist',
#               'Senior Statistical Data Scientist - across the GSS',
#               'Senior Teaching Fellow in Business Analytics and Data Scient...',
#               'Data Scientist',
#               'Head of Product - Applied AI/ML (Artificial Intelligence / M...',
#               'Data Scientist',
#               'MASTER DATA SCIENTIST',
#               'Senior Data Scientist',
#               'Data Services Analyst, Endeavor Analytics',
#               'Data Scientist (Contract) - Ecommerce',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Graduate Data Scientist - Insurance Consulting (Reigate or L...',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Sales Data Scientist',
#               'Data Scientist (m/w/d)',
#               'DATA SCIENCE TEAM LEAD - FINTECH',
#               'DATA SCIENCE CONSULTANT LONDON',
#               'Data Engineer/Scientist',
#               'Brand Sales Specialist - Data & AI',
#               'DATA SCIENTIST',
#               'Data Scientist (Contract) - Forecasting',
#               'Core Data Scientist/Engineer',
#               'Vice President – Data Science',
#               'Data Scientist',
#               'Lead Decision Data Scientist',
#               'Senior Data Scientist, Consumer Experience',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist (Contract) - Geospatial',
#               'Data Scientist - Predictive Analytics',
#               'Data Scientists - Consulting',
#               'Research Scientist',
#               'Data Scientist',
#               'Customer Facing Data Scientist',
#               'Data Scientist',
#               'Data Scientist – Independent Media Agency',
#               'Machine Learning Scientist - Data Science & AI',
#               'Data Scientist (Geospatial) - Contract',
#               'Data Scientist (Energy / Decarbonisation)',
#               'Data Scientist - Retail',
#               'Data Scientist',
#               'Data Scientist - Marketing Science',
#               'Analyst, Data Science (12 month Fixed-Term Contract)',
#               'Data Scientist - FTC - 3- Month Rolling Contract',
#               'Data Scientist, B2B Demand Generation',
#               'Principal Data Scientist',
#               'Snr. Data Scientist, Market Research',
#               'Senior Data Scientist',
#               'Data Scientist – 51594',
#               'Manager, Research Data Science',
#               'Head of E-Commerce Analytics',
#               'AI/ML Engineer',
#               'Data Scientist, Performance Marketing',
#               'Senior Data Scientist',
#               'Head of Data Science- Health',
#               'Data Scientist (Remote)',
#               'Risk Analyst - Quantitative Modelling & Analysis, RALC (SRS)',
#               'Data Scientist Director',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Data Scientist (Contract) - Statistics',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'NLP Data Scientist',
#               'Senior Data Scientist London',
#               'Data Scientist - Predictive Analytics',
#               'Manager, Data and Analytics- Capital Markets, Financial Serv...',
#               'Data Scientist – London',
#               'Data Scientist',
#               'Software Engineer - Machine Learning',
#               'Senior Data Scientist London',
#               'Advisor, Data science and analytics',
#               'Principal Data Scientist',
#               'Global Markets Division - SFL Strats - Associate - London',
#               'Data Scientist – 51594',
#               'Applied Scientist - Deep Learning',
#               'Senior Data Scientist',
#               'Senior Supply Chain Analytics Consultant',
#               'Data Analyst - Rare Diseases',
#               'Data Scientist',
#               'Data & AI Business Analyst',
#               'Data Scientist',
#               'Data Scientist (Multiple Seniorities)',
#               'Advisor, Data science and analytics',
#               'Analytics Engineer',
#               'Data Scientist',
#               'Head of Data Science',
#               'Python Software Engineer - Cloud / Data Science',
#               'Data Science Consultant (FTC)',
#               'Data Scientist',
#               'Artificial Intelligence',
#               'Data Scientist',
#               'Senior Data Scientist (m/f/d)',
#               'Lead Data Scientist',
#               'AI/ML Engineer',
#               'Machine Learning Engineer',
#               'Data Scientist Python - Hedge Fund',
#               'AI & ML DevOps Engineer - Contract',
#               'Data Scientist',
#               'Senior Machine Learning Engineer',
#               'Senior Data Scientist',
#               'Machine Learning Engineer',
#               'Data Science Lead',
#               'Machine Learning Engineer (Remote)',
#               'Lead/ Senior Data Scientist',
#               'Data Analyst, Renewable Energy',
#               'Senior Supply Chain Analytics Consultant',
#               'Data Scientist - Senior Consultant',
#               'Sr. Manager, Data Science',
#               'AI/ML Engineer',
#               'Data Scientist – London',
#               'Data Scientist – Independent Media Agency',
#               'Decision Scientist',
#               'Data Science Analyst, Ascential Marketing Division',
#               'Senior Data Scientist London',
#               'NLP Data Scientist (Mid-Senior Level)',
#               'Python Developer - AI SAAS',
#               'Data Analyst - Rare Diseases',
#               'Advisor, Data science and analytics',
#               'Data Scientist',
#               'Manager, Advanced Data Insight Analytics',
#               'Staff Deep Learning Engineer',
#               'Data Scientist',
#               'Lead Data Scientist',
#               'Data Scientist – 51594',
#               'Data Science Consultant',
#               'Staff Deep Learning Engineer',
#               'Data Scientist',
#               'Lead Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Machine Learning Scientist',
#               'Product Data Analyst',
#               'DATA SCIENTIST',
#               'Head of Data Science',
#               'Specialist, Data Science',
#               'NLP Data Scientist',
#               'Big Data Engineer - Hadoop, Spark, AWS',
#               'Data Science Analyst Fixed Term Contract London',
#               'Statistician',
#               'Natural Language Processing (NLP)',
#               'Part-time Data Scientist',
#               'Data Scientist',
#               'Head of E-Commerce Analytics',
#               'Data Science Consultant',
#               'Big Data Engineer - Hadoop, Spark, AWS',
#               'Data Science Analyst Fixed Term Contract London',
#               'Head of Data Science',
#               'Data Science and Analytics Consultant/Researcher',
#               'AI Solutions Manager, Life Science',
#               'AI Advisory / Data Science Advisory, Senior Manager',
#               'Senior Data Scientist',
#               'Machine Learning Engineer (Contract) - Outside IR35',
#               'Biological Data Science Specialist',
#               'Machine Learning Researcher',
#               'Data Scientist',
#               'Senior Applied Scientist - Traffic & Pricing Platform (w/d/m...',
#               'Sr Data Scientist',
#               'Manager, Data and Analytics- Capital Markets, Financial Serv...',
#               'Machine Learning Engineer - Discover',
#               'Software Engineer, Machine Learning',
#               'Data Science Consultant',
#               'Staff Deep Learning Engineer',
#               'Management Consultant - Supply Chain Analytics',
#               'Machine Learning Engineer',
#               'Advanced Data Insight Analyst III (Marketing Analytics)',
#               'C# Developer: NLP Team',
#               'NLP Data Scientist',
#               'Data Scientist',
#               'Data Science Associate Consultant',
#               'Part Time Faculty for Business Analytics',
#               'Principal Data Scientist',
#               'Senior Audio Machine Learning Engineer',
#               'Marketing Data Scientist',
#               'Data Scientist / AI Engineer',
#               'Staff Machine Learning Research Engineer - Cortex Recommende...',
#               'Senior Data Scientist',
#               'Strategic Consultant - Data Science & Analytics',
#               'Data Science Manager, London',
#               'Machine Learning Engineer',
#               'Data Scientist',
#               'Data Scientist Python - Hedge Fund',
#               'Senior Data Scientist, Insights & Innovation, UK',
#               'Pricing Transformation Big Data Analyst',
#               'Data Scientist, B2B Marketing',
#               'Data Scientist',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Data Scientist',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Machine Learning Platform Engineer',
#               'Junior data science engineer',
#               'Data Science Consultant',
#               'Analyst Healthcare Analytics homebased',
#               'Visual Analytics Consultant',
#               'Data Scientist',
#               'AI Engineer',
#               'Natural Language Processing Engineers',
#               'Head of Data Science',
#               'Data Engineer – Data Science',
#               'Pricing Data Scientist',
#               'Data Scientist - Health Outcomes',
#               'Market Director - Forensic Data Analytics - London',
#               'Data Scientist - Python Developer',
#               'Data Science Lead',
#               'Machine Learning Engineer (Remote)',
#               'Lead/ Senior Data Scientist',
#               'Data Analyst, Renewable Energy',
#               'Senior Data Scientist / ML Engineer',
#               'Data Scientist - Senior Consultant',
#               'Sr. Manager, Data Science',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Senior Strategic Consultant - Data Science & Analytics',
#               'Senior Data Scientist - Global participation',
#               'Senior Data Scientist – London',
#               'Data Scientist',
#               'Data Scientist - NLP Specialist',
#               'BIG DATA ARCHITECT',
#               'Principal Data Scientist, Reinforcement Learning',
#               'Data Scientist (Contract) - Insights',
#               'Principal Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist/ Senior Data Scientist',
#               'Lead/ Senior Data Scientist',
#               'Machine Learning Lead',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Senior Data Scientist, Insights & Innovation, UK',
#               'Principal Applied Scientist',
#               'Senior Applied Scientist - Information Retrieval and Natural...',
#               'Vice President, Advanced Analytics & Prototyping, SpendingPu...',
#               'Data Scientists - Consulting',
#               'Data Analyst, Renewable Energy',
#               'Data Scientist (Geospatial) - Contract',
#               'Data Scientist (NLP) - Inside IR35',
#               'Data Scientist',
#               'Senior Game Data Scientist - Racing',
#               'Head of Data Science',
#               'Engineering Manager - Machine Learning - Health',
#               'AI Architect – London',
#               'Data Lab Architect',
#               'BI Data Manager - Analytics',
#               'Data Scientist',
#               'Data Scientists - Consulting',
#               'Machine Learning Engineer',
#               'Analytics Engineer – Qlik',
#               'Machine Learning Engineer',
#               'Senior Data Scientist - Forecasting',
#               'Senior Data Scientist / Operational Researcher',
#               'AI Architect – London',
#               'Senior Engineer – Machine Learning and Computer Vision',
#               'Applied Scientist - Automated Reasoning',
#               'Senior Data Scientist, Product',
#               'Quantitative Researcher (Data Science/Machine Learning/Mathe...',
#               'Data Science Director',
#               'Lecturer in Climate Physics, Data Science in Climate Energy,...',
#               'Data Scientist',
#               'Senior Applied Scientist - Traffic & Pricing Platform (w/d/m...',
#               'Analytics Engineer – Qlik',
#               'Staff Product Manager - Machine Learning Platform',
#               'LEAD DATA ENGINEER – PYTHON, SQL – DATA SCIENCE – FINANCIAL...',
#               'CIB Investment Bank - Applied AI & Machine Learning - Execut...',
#               'Data Science Leader',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Data Scientist',
#               'Principal Data Scientist - Remote, UK',
#               'Machine Learning Engineer - Kubrick',
#               'Data Scientist',
#               'Data Scientist',
#               'Senior Data Scientist - Badoo',
#               'Senior Data Scientist, Product Analytics',
#               'Machine Learning Scientist Intern',
#               'Computer Vision Deep Learning Engineer',
#               'Senior Data Scientist',
#               'Capital, Control and Operations Big Data Architect',
#               'Natural Language Processing (NLP)',
#               'Applied Scientist - Information Retrieval and Natural Langua...',
#               'Quantitative Researcher (Data Science/Machine Learning/Mathe...',
#               'Database & Data Science Developer',
#               'Data Scientist',
#               'Data Scientist',
#               'Senior Data Architect / Data Scientist - 100% Remote across...',
#               'Senior Data Scientist - 8 MONTH FTC',
#               'Principal Consultant - Analytics Consulting',
#               'Management Consultant – Digital Marketing Analytics',
#               'Lead Data Scientist',
#               'Big Data and Data Science Platforms - Tech lead - FS',
#               'Director, Artificial Intelligence Consulting',
#               'Digital Web Analytics Manager',
#               'Senior Specialist, Data Science',
#               'Associate Director, Digital and Analytics Operations - ICR R...',
#               'Senior Data Scientist',
#               'Pre-Sales Solution Engineer, BI & Analytics',
#               'Analytics Consultant',
#               'Data & Analytics Senior Manager, Digital Pre-school Centre o...',
#               'Research Data Scientist',
#               'Legal Technologist - Machine Learning & Artificial Intellige...',
#               'Head of Data Science',
#               'Pre-Sales Solution Engineer, BI & Analytics',
#               'Head of Data Science',
#               'LEAD DATA ENGINEER – PYTHON, SQL – DATA SCIENCE – FINANCIAL...',
#               'Business Intelligence Engineer - Customer behavior & marketi...',
#               'Lead Data Scientist',
#               'AI Engineer',
#               'Machine Learning Engineer',
#               'Programme Management, Data Science Lead',
#               'Sr Machine Learning Engineer',
#               'Associate Educator, Data Scientist',
#               'Head of Data Science',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Machine Learning Researcher',
#               'Transaction Monitoring Modelling & Analytics',
#               'Algorithm & Software Developer (Machine Learning, Computer V...',
#               'Data Scientist - Machine Learning (Python/SQL)',
#               'Machine Learning Engineer',
#               'Data Scientist Director',
#               'Project Manager, Data & Analytics',
#               'Machine Learning Research Engineer',
#               'Digital Audit Advanced Analytics Senior Associate',
#               'Software Engineer - Machine Learning',
#               'Retail Senior Data Scientist / Retail Data Science Manager',
#               'Machine Learning Team Lead',
#               'Educator, Data Scientist',
#               'Head of Data Science - London - (Cutting Edge NLP!!)',
#               'Senior Data Scientist/ Machine Learning Developer',
#               'Senior Applied Scientist - Information Retrieval and Natural...',
#               'Research Scientist, Natural Language Processing (PhD)',
#               'Senior Data Scientist - UK',
#               'Principal Data Science Consultant',
#               'Machine learning Software Engineer - Senior Associate',
#               'Data Scientist | Python | NLP | London | Contract',
#               'Machine Learning Lead',
#               'AI-Quant - Junior',
#               'Head of Data Science - London - (Cutting Edge NLP!!)',
#               'Senior Data Scientist/ Machine Learning Developer',
#               'Lead Data Scientist',
#               'Data Scientist',
#               'Senior Data Science Engineer',
#               'Senior Data Scientist',
#               'Head of Data Science',
#               'Data Scientist',
#               'Data Scientist (Multiple Seniorities)',
#               'Senior Data Science Engineer',
#               'Machine Learning Engineer',
#               'Data Science Manager - EMEA',
#               'Full Cycle Data Scientist - FinTech',
#               'Machine Learning Engineer',
#               'Machine Learning Engineer',
#               'Analytics Strategy Manager',
#               'Research Data Scientist',
#               'Computer Vision Deep Learning Engineer',
#               'Deep Learning Engineer',
#               'Machine Learning Research Scientist',
#               'Senior Applied Scientist',
#               'Data Scientist - Cancer',
#               'Quantitative Researcher in Natural Language Processing (NLP)',
#               'VP Customer Success @ Leading Machine-Learning SaaS Platform',
#               'Python Developer SQL Machine Learning AWS',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Faculty Data Science & Data Engineering Fellowship (Oct 2021...',
#               'Machine Learning Engineer - Genomic Data',
#               'Technical Product Manager - Data AI Machine Learning',
#               'Analytics Cloud Specialist, EMEA',
#               'NLP Data Scientist',
#               'Product Manager – AI & Machine Learning',
#               'Account Manager @ Machine-Learning Startup',
#               'Product Manager & Data Scientist',
#               'Senior Data Scientist | Search & Rank',
#               'Financial Quant/Data Science - Fintech - London or Paris',
#               'Senior Manager, Customer Analytics',
#               'Data Scientist',
#               'Machine Learning Engineer (Contract) - Outside IR35',
#               'AI Advisory / Data Science Advisory, Senior Manager',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Analytics Strategy Manager',
#               'Digital Web Analytics Manager',
#               'Big Data Engineer',
#               'Analytics Engineer – Qlik',
#               'AI Architect – London',
#               'Machine Learning Research Engineer',
#               'Data Scientist',
#               'Machine Learning Engineer',
#               'Associate Director, Digital and Analytics Operations - ICR R...',
#               'Senior Data Scientist',
#               'Pre-Sales Solution Engineer, BI & Analytics',
#               'Data & Analytics Senior Manager, Digital Pre-school Centre o...',
#               'Senior Data Scientist',
#               'Director – Analytics & AI',
#               'Principal Machine Learning Engineer',
#               'Senior Business Analyst/Data architect',
#               'Big Data Solutions Architect – London',
#               'Financial Crime Analytics Manager',
#               'Site Reliability Engineer - Machine Learning',
#               'Machine Learning Engineer',
#               'Agile Project Manager - Data Analytics',
#               'Data Scientist',
#               'PhD Student, London (AI)',
#               'Data Scientist - Advanced Analytics & Insight',
#               'Lead AI/ML Engineer',
#               'Data Science Team Leader - Robotics',
#               'Lead Data Scientist',
#               'Account Manager, Data Science and Tool Development',
#               'ARTIFICIAL INTELLIGENCE SPECIALIST',
#               'Senior Analytics Translator',
#               'Senior Data Scientist',
#               'AI Success Director',
#               'Head of Data Science - eCommerce',
#               'Lead Data Scientist',
#               'Software Engineer, Machine Learning',
#               'AI/ML Engineer - Production',
#               'Machine Learning Engineer',
#               'Senior Software Engineer (Data Science)',
#               'PSG Business Intelligence & Data Science Manager',
#               'Principal Data Scientist',
#               'Senior Analytics Translator',
#               'Machine Learning Engineer - Golf Start-Up - Python AWS ML Pr...',
#               'Senior Data Scientist',
#               'AI Success Director',
#               'Head of Data Science - eCommerce',
#               'Data Scientist – Insurance',
#               'Lead Data Scientist',
#               'Data Scientist - London',
#               'Data Scientist (Product)',
#               'Software Engineer, Machine Learning',
#               'AI/ML Engineer - Production',
#               'Principal Machine Learning Scientist - Patient Data Analytic...',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Data Scientist',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Data Scientist - Manager - UKI Assurance - Forensic Data Ana...',
#               'Data Scientist (Geospatial) - Contract',
#               'Senior Game Data Scientist - Racing',
#               'Data Scientist',
#               'Engineering Manager - Machine Learning - Health',
#               'Head of Data Science',
#               'Data Lab Architect',
#               'Data Scientists - Consulting',
#               'Machine Learning Engineer',
#               'Senior Data Scientist - Forecasting',
#               'Database & Data Science Developer',
#               'Market Director - Forensic Data Analytics - London',
#               'Data Scientist - Python Developer',
#               'Apple Media Products (AMP)- Big Data Engineer - Core Marketi...',
#               'Software Engineer, Machine Learning & Program Analysis',
#               'Head Of Data & Analytics',
#               'Data Scientist',
#               'Senior Software Engineer, AI/ML Production',
#               'Partner Engineer - Network Analytics',
#               'Senior Machine Learning Research Engineer',
#               'Computer Vision Engineer, Deep Learning',
#               'Junior Data Science Consultant',
#               'Senior Data Scientist',
#               'Deep Learning Scientist',
#               'Professor in Computer Vision and Machine Learning',
#               'Data Analytics Lead',
#               'Data Scientist Python PhD',
#               'Data Science Lecturer',
#               'Principal Machine Learning Engineer',
#               'Senior Consultant, Medallia Strategy Analytics',
#               'Deep Learning Engineer',
#               'Principal Machine Learning Engineer REMOTE',
#               'Senior Software Engineer (Data Science)',
#               'Senior Data Scientist',
#               'Audience Measurement - Data Science Product Manager',
#               'Senior Statistician, Data Science',
#               'Technical Product Manager (Machine Learning)',
#               'Senior Data Scientist',
#               'Computer Vision Machine Learning Engineer',
#               'Machine Learning Research Engineer',
#               'Pre-sales Solutions Architect - Data & AI',
#               'Data Scientist',
#               'Senior NLP Researcher',
#               'Software Engineer - Data/Machine Learning - £550/650pd',
#               'Financial Crime Analytics Manager',
#               'Audio Machine Learning Data Engineer',
#               'BI Data Manager - Analytics',
#               'Professor in Computer Vision and Machine Learning',
#               'Deep Learning Engineer',
#               'Big Data Engineer - Hadoop, Spark, Cloud',
#               'Principal Scientist - Patient Data Analytics',
#               'AI Success Director',
#               'Adobe Analytics Lead',
#               'Data Scientist',
#               'Analytics Manager London',
#               'Data Science Content Developer',
#               'Algorithm & Software Developer (Machine Learning, Computer V...',
#               'Machine Learning Engineer (Two way recommender systems)',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Data Scientist',
#               'FINANCE ANALYTICS MANAGER, PROPERTY & CASUALTY',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Legal Technologist - Machine Learning & Artificial Intellige...',
#               'Senior AI/ML Engineer - Sequence Learning',
#               'Python Engineer Machine Learning SQL',
#               'Digital Analytics Manager London, United Kingdom Consumer',
#               'Senior Data Scientist',
#               'Statistical Programmer I (SAS or R) – Real World Evidence (o...',
#               'Quantitative Researcher in Natural Language Processing (NLP)',
#               'VP Customer Success @ Leading Machine-Learning SaaS Platform',
#               'SENIOR DATA SCIENTIST',
#               'Python Developer SQL Machine Learning AWS',
#               'Senior Data Scientist',
#               'Senior Applied Research Scientist, NLP',
#               'Senior Machine Learning Engineer',
#               'Machine Learning Engineer',
#               'Digital Analytics Manager',
#               'Director of Applied Data Science',
#               'Senior Machine Learning Research Engineer',
#               'Director, Data Science',
#               'Senior Biostatistician (FSP) Home Based',
#               'Apple Media Products (AMP)- Big Data Engineer - Core Marketi...',
#               'Data Scientist',
#               'Data Scientist',
#               'Consulting Project Manager Analytics & Clinical Services',
#               'Director - Analytics & AI',
#               'Data Science Team Leader - Robotics',
#               'Principal Data Science Consultant',
#               'Machine Learning (Contract) - Outside IR35',
#               'Machine Learning Research Engineer',
#               'Staff Machine Learning Engineer',
#               'Machine Learning Engineer III',
#               'Senior Bioinformatics Data Scientist',
#               'Principal Machine Learning Engineer',
#               'Senior Data Science Engineer',
#               'Data Scientist',
#               'Product Manager (Data Science)',
#               'Big Data Lead',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Data Science – Recruitment Consultant – City of London',
#               'NLP Developer/ML Engineer',
#               'FINANCE ANALYTICS MANAGER, PROPERTY & CASUALTY',
#               'Lead Data Engineer - AI Consultancy - London',
#               'Lead NLP Data Scientist',
#               'Senior Consultant, Advanced Analytics (Remote)',
#               'Head of Data Science',
#               'Machine Learning Engineer',
#               'Real World Data Senior Biostatistician',
#               'Data Science Consultant - Software Product',
#               'Data Scientist',
#               'Senior Research Data Scientist',
#               'Machine Learning Developer',
#               'Senior Manager Data and Analytics',
#               'Data Scientist/ Senior Data Scientist',
#               'Lead Machine Learning Teacher',
#               'Genomics Data Scientist',
#               'Cancer Genomics Data Scientist',
#               'Big Data Engineering Lead',
#               'Head of Data Science',
#               'Data Scientist - Government',
#               'AI-Quant - Intermediate',
#               'Machine Learning Software Engineer',
#               'Machine Learning Engineer - Trading',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - ML/NLP',
#               'NLP Data Scientist',
#               'Lead Data Science Consultant',
#               'Data Scientist',
#               'Senior Advisor, Data science and Analytics',
#               'Senior Machine Learning Engineer',
#               'Senior Data Scientist - Forecasting',
#               'Software Engineer (AI / ML)',
#               'Robotics Research Engineer - Machine Learning',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'NLP Data Scientist',
#               'Big Data DevOps Engineer',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Senior Machine Learning Engineer - Leading Data/ AI Consulta...',
#               'Senior Product Manager (Data Science/ AI)',
#               'AI Success Director (Spanish Language Requirements)',
#               'Product Manager (Data Science)',
#               'Senior Analytics Engineer- DBT',
#               'Senior Machine Learning Engineer',
#               'Principal Biostatistician',
#               'Software Engineer, AR Machine Learning',
#               'Senior Data Scientist',
#               'Customer-Facing Data Scientists - London',
#               'Senior Data Scientist',
#               '1774- Sr. Director, Analytics and Modeling',
#               'Senior Software Engineer (Python), AI/Machine Learning - Lon...',
#               'Data Scientist (Growth Tribe)',
#               'Director, Patient Services Analytics and Insights',
#               'Senior Data Scientist',
#               '1774- Sr. Director, Analytics and Modeling',
#               'Senior Software Engineer (Python), AI/Machine Learning - Lon...',
#               'Data Scientist (Growth Tribe)',
#               'Director, Patient Services Analytics and Insights',
#               'Machine Learning/Computer Vision Scientist (Home W',
#               'Digital Analytics Manager',
#               'Pre-Sales Solution Engineer, BI & Analytics, Tableau',
#               'Data Science Manager',
#               'Lead Machine Learning Scientist',
#               'NLP Data Scientist',
#               'Applied Machine Learning Scientist',
#               'Senior Data Science Consultant',
#               'ARTIFICIAL INTELLIGENCE & ALGORITHM PRO',
#               'Senior Machine Learning Engineer',
#               'Senior Bioinformatics Data Scientist',
#               'Polyglot Engineer (AI Start-Up) - Python/ Golang/ Javascript',
#               'Performance Analytics Manager',
#               'Manager, Global Analytics Platform',
#               'C++ Developer - Risk, Machine Learning - London',
#               'Machine Learning Engineer; Computer Vision, Data S',
#               'Lead Engineer - Python - Machine Learning',
#               'Senior Lead Analyst - Analytics Technology',
#               'Lead Data Scientist',
#               'Principal Statistician',
#               'Senior Machine Learning Scientist - DeepTech Startup (AgriTe...',
#               'Senior Machine Learning Engineer',
#               'Principal Data Scientist (Supply)',
#               'Data Scientist',
#               'Product Analytics Manager',
#               'Principal Biostatistician (FSP) Home Based',
#               'MACHINE LEARNING SPECIALIST',
#               'Quantitative Financial Modeller – Balance Sheet & Analytics',
#               'Data Analytics Manager – Telecommunications',
#               'Senior AI/ML Engineer',
#               'Senior Biostatistician (FSP) Home Based',
#               'Technical Coach: Data Science',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Machine Learning Engineer',
#               'Senior Business Intelligence Consultant – CRM Analytics',
#               'Head of Analytics',
#               'Senior Machine Learning Engineer',
#               'Recruitment Consultant - Data Science',
#               'Lead Data Scientist / R&D Engineer',
#               'Senior Analyst/Developer, Pricing Analytics & Models (PAM) &...',
#               'Product Manager | AI',
#               'Senior Data Science Engineer',
#               'Senior ML Engineer',
#               'Technical BA - Analytics & Automation',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior Software Engineer - Machine Learning',
#               'Machine Learning Engineer',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Software Engineer (AI / ML)',
#               'Senior Product Manager, Database Capabilities (Graph & Time...',
#               'Senior Statistician',
#               'Data Analytics Manager – Telecommunications',
#               'Director, Patient Services Analytics and Insights',
#               'Senior Machine Learning Engineer',
#               'Product Manager | AI',
#               'Senior Data Science Engineer',
#               'Senior ML Engineer',
#               'Machine Learning Ops Engineer',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior ML Engineer (contract)',
#               'Data Scientist',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Principal Data Scientist - Remote, UK',
#               'Data Scientist',
#               'Senior Machine Learning Scientist',
#               'Senior Data Scientist',
#               'Business Analyst - Analytics',
#               'Analytics Cloud Specialist, EMEA',
#               'BIG DATA ARCHITECT',
#               'Principal Consultant - Analytics Consulting',
#               'Solution Architect - Technical Presales (Big Data, Analytics...',
#               'Pre-sales Solutions Architect - Data & AI - Retail or CPG',
#               'Machine Learning Engineer',
#               'Product Analytics Manager',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Database & Data Science Developer',
#               'Data Scientist',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Software Engineer - Machine Learning',
#               'Senior Machine Learning Engineer',
#               'Senior Linux/DevOps Engineer with focus on Big Data',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Senior Product Manager, Database Capabilities (Graph & Time...',
#               'Robotics Research Engineer - Machine Learning',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Econometric Analyst - Machine Learning',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Technical BA - Analytics & Automation',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Big Data DevOps Engineer',
#               'Senior Technical Product Manager, AI & Machine Learning, Rea...',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Data Scientist',
#               'Data Scientist',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Apple Media Products (AMP)- Big Data Engineer - Core Marketi...',
#               'Data Scientist',
#               'Data Scientist',
#               'Partner Engineer - Network Analytics',
#               'Senior Data Scientist',
#               'Data Engineer – Specialty Analytics',
#               'Data Science Manager',
#               'Analytics Consultant',
#               'Market Director - Forensic Data Analytics - London',
#               'Data Scientist - Python Developer',
#               'Machine Learning Platform Engineer',
#               'Principle Data Scientist',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'Senior Software Engineer (Data Science)',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Research Data Scientist',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Machine Learning Engineer',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Linux/DevOps Engineer with focus on Big Data',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Technical BA - Analytics & Automation',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'NLP Data Scientist',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Senior Product Manager, Database Capabilities (Graph & Time...',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'NLP Data Scientist',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Machine Learning Engineer',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Linux/DevOps Engineer with focus on Big Data',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
# ...
#               nan,
#               nan,
#               '£59688 - £67767 a year',
#               '£40000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               '£85000 - £95000 a year',
#               nan,
#               nan,
#               '£53000 a year',
#               nan,
#               '£40000 - £50000 a year',
#               nan,
#               '£32000 a year',
#               '£35000 - £45000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £80000 a year',
#               '£80000 - £110000 a year',
#               '£60000 - £65000 a year',
#               nan,
#               nan,
#               '£95000 a year',
#               '£70000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£40000 - £50000 a year',
#               nan,
#               '£50000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£85000 - £95000 a year',
#               nan,
#               '£80000 - £100000 a year',
#               nan,
#               '£390 - £425 a day',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£55000 - £75000 a year',
#               nan,
#               '£70000 - £100000 a year',
#               '£32000 a year',
#               '£90000 - £110000 a year',
#               nan,
#               '£34000 - £38000 a year',
#               nan,
#               nan,
#               '£68139 - £75710 a year',
#               nan,
#               nan,
#               '£120000 - £130000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£500 - £600 a day',
#               '£75000 - £100000 a year',
#               nan,
#               '£120000 - £130000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£65000 - £70000 a year',
#               nan,
#               '£40000 - £55000 a year',
#               '£40000 - £110000 a year',
#               nan,
#               '£70000 - £90000 a year',
#               nan,
#               '£80000 - £120000 a year',
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               '£40000 - £65000 a year',
#               nan,
#               '£60000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£80000 - £95000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£75000 a year',
#               '£500 - £550 a day',
#               '£110000 - £130000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£75000 - £95000 a year',
#               nan,
#               nan,
#               '£32000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£90000 a year',
#               '£65000 - £75000 a year',
#               nan,
#               nan,
#               '£65000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£80000 - £95000 a year',
#               nan,
#               '£60000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               '£40000 - £45000 a year',
#               '£70000 a year',
#               nan,
#               '£50000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£35000 - £45000 a year',
#               '£53000 a year',
#               nan,
#               '£32000 a year',
#               '£40000 - £50000 a year',
#               nan,
#               nan,
#               '£450 - £500 a day',
#               nan,
#               nan,
#               nan,
#               '£110000 - £120000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£350 - £400 a day',
#               nan,
#               nan,
#               nan,
#               '£50000 - £62000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£40000 - £50000 a year',
#               nan,
#               '£80000 - £85000 a year',
#               nan,
#               nan,
#               '£65000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               '£70000 - £100000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£65000 a year',
#               nan,
#               '£55000 - £75000 a year',
#               '£60000 - £70000 a year',
#               '£70000 a year',
#               nan,
#               nan,
#               nan,
#               '£550 - £650 a day',
#               '£65000 - £75000 a year',
#               nan,
#               '£570 a day',
#               nan,
#               '£60000 a year',
#               '£90000 - £120000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£75000 - £85000 a year',
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£55000 - £65000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               '£60000 - £80000 a year',
#               nan,
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£550 - £650 a day',
#               '£70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £100000 a year',
#               '£60000 - £90000 a year',
#               '£80000 - £95000 a year',
#               nan,
#               nan,
#               '£37000 a year',
#               nan,
#               nan,
#               nan,
#               '£75000 - £95000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£55000 - £75000 a year',
#               '£50000 - £60000 a year',
#               '£60000 a year',
#               nan,
#               '£50000 - £100000 a year',
#               '£85000 - £100000 a year',
#               nan,
#               nan,
#               '£100000 a year',
#               nan,
#               nan,
#               nan,
#               '£40000 - £50000 a year',
#               '£65000 - £75000 a year',
#               '£85000 - £100000 a year',
#               nan,
#               nan,
#               '£85000 - £100000 a year',
#               nan,
#               nan,
#               '£60000 - £80000 a year',
#               '£65000 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               nan,
#               '£60000 - £90000 a year',
#               '£70000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               '£40000 - £70000 a year',
#               nan,
#               nan,
#               '£70000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £90000 a year',
#               nan,
#               nan,
#               '£35000 - £40000 a year',
#               '£50000 - £60000 a year',
#               nan,
#               '£60000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £86000 a year',
#               '£35000 - £45000 a year',
#               nan,
#               '£90000 a year',
#               '£30000 - £55000 a year',
#               '£75000 - £95000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               '£65000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £70000 a year',
#               nan,
#               '£40000 - £45000 a year',
#               nan,
#               nan,
#               '£25000 - £35000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £45000 a year',
#               '£53000 a year',
#               nan,
#               '£32000 a year',
#               nan,
#               '£40000 - £50000 a year',
#               '£100000 - £120000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£28000 - £35000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£35000 - £45000 a year',
#               nan,
#               nan,
#               '£53000 a year',
#               '£40000 - £50000 a year',
#               '£32000 a year',
#               nan,
#               nan,
#               nan,
#               '£45000 a year',
#               '£50000 - £55000 a year',
#               nan,
#               '£85000 - £100000 a year',
#               '£60000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               '£350 - £400 a day',
#               '£40000 - £65000 a year',
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               '£50000 - £55000 a year',
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               ...]})

# %%
spare_res = results.copy()

# %%
results
# Out:
# defaultdict(list,
#             {'title': ['Data Scientist',
#               'Data Scientist',
#               'Data Science Intern',
#               'Data Science Intern',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist - R& Python',
#               'Junior Data Scientist',
#               'Associate Data Scientist',
#               'Data Scientist',
#               'VelocITy Data & AI Graduate Programme, UK',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Audience Measurement - Junior Data Scientist',
#               'Data Scientist',
#               'Data Scientist Internship',
#               'Product Data Scientist',
#               'Data Governance Associate Scientist',
#               'Data Scientist - Associate',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Science Intern',
#               'DATA SCIENTIST | VERV | LONDON OR SHEFFIELD',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Science Intern',
#               'Research Scientist',
#               'Data Scientist',
#               'Graduate Data Scientist - Insurance Consulting (Reigate or L...',
#               'Junior Data Scientist - London',
#               'DATA SCIENCE CONSULTANT LONDON',
#               'Senior Data Scientist - People Recommendations',
#               'Data and Analytics Strategy Consultant',
#               'Data Scientist',
#               'Data Scientist, Causal Inference',
#               'Senior Data Scientist, Personal Banking',
#               'Data Scientist - open to remote working',
#               'Data Scientist',
#               'Data Insight - Analytics Strategist',
#               'Data Science Internship',
#               'Customer Analytics Data Scientist Senior Associate',
#               'Senior Data Scientist - Badoo',
#               'Intern - Data Scientist',
#               'Junior Data Scientist/Analyst',
#               'Data Analytics Specialist',
#               'Fraud Data Scientist',
#               'Machine Learning Scientist - Data Science & AI',
#               'Data Scientist III (Meta Bidding)',
#               'PSG Associate Data Scientist',
#               'Sales Data Scientist',
#               'Machine Learning Scientist Intern',
#               'Intern - Machine Learning Engineer',
#               'Intern, AI Lab UK (Summer)',
#               'Analyst, Data Science (12 month Fixed-Term Contract)',
#               'Lead Data Scientist',
#               'Vice President – Data Science',
#               'Machine Learning Engineer, Risk & Abuse',
#               'Data Scientist',
#               'Machine Learning Engineer Internship',
#               'Data Scientist – Aerospace and Defence',
#               'Python Software Engineer - Cloud / Data Science',
#               'Higher Statistical Data Scientist - across the GSS',
#               'Healthcare Data Scientist',
#               'Data Scientist',
#               'Head of Data Science, Financial Crime',
#               'Data Scientist',
#               'Data Scientist, Product Analytics',
#               'Data Scientist',
#               'Machine Learning Engineer - Data Science & AI',
#               'Data Scientist, Product',
#               'Data Scientist',
#               'Junior Data Scientist',
#               'Data Scientist, Legal',
#               'Research Data Scientist',
#               'Senior Data Scientist - Marketing',
#               'MSc Data Science Online Tutor',
#               'Sales Data Scientist',
#               'Data Scientist, Product Analytics',
#               'Senior Data Scientist, Operations and Financial Crime',
#               'Data Science Internship',
#               'Data Scientist',
#               'Data Scientist (Tableau) – Remote',
#               'Senior Data Scientist',
#               'DATA SCIENTIST',
#               'Data Scientist – Aerospace and Defence',
#               'Data Scientist -Ranking & Recommendations',
#               'Data Scientist (Contract) - Experimentation',
#               'Data Scientist (Contract) - Simulation',
#               'Data Scientist (Contract) - Forecasting',
#               'Machine Learning Data Engineer',
#               'Data Scientist',
#               'Senior Statistical Data Scientist - across the GSS',
#               'Senior Teaching Fellow in Business Analytics and Data Scient...',
#               'Data Scientist',
#               'Head of Product - Applied AI/ML (Artificial Intelligence / M...',
#               'Data Scientist',
#               'MASTER DATA SCIENTIST',
#               'Senior Data Scientist',
#               'Data Services Analyst, Endeavor Analytics',
#               'Data Scientist (Contract) - Ecommerce',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Graduate Data Scientist - Insurance Consulting (Reigate or L...',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Sales Data Scientist',
#               'Data Scientist (m/w/d)',
#               'DATA SCIENCE TEAM LEAD - FINTECH',
#               'DATA SCIENCE CONSULTANT LONDON',
#               'Data Engineer/Scientist',
#               'Brand Sales Specialist - Data & AI',
#               'DATA SCIENTIST',
#               'Data Scientist (Contract) - Forecasting',
#               'Core Data Scientist/Engineer',
#               'Vice President – Data Science',
#               'Data Scientist',
#               'Lead Decision Data Scientist',
#               'Senior Data Scientist, Consumer Experience',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist (Contract) - Geospatial',
#               'Data Scientist - Predictive Analytics',
#               'Data Scientists - Consulting',
#               'Research Scientist',
#               'Data Scientist',
#               'Customer Facing Data Scientist',
#               'Data Scientist',
#               'Data Scientist – Independent Media Agency',
#               'Machine Learning Scientist - Data Science & AI',
#               'Data Scientist (Geospatial) - Contract',
#               'Data Scientist (Energy / Decarbonisation)',
#               'Data Scientist - Retail',
#               'Data Scientist',
#               'Data Scientist - Marketing Science',
#               'Analyst, Data Science (12 month Fixed-Term Contract)',
#               'Data Scientist - FTC - 3- Month Rolling Contract',
#               'Data Scientist, B2B Demand Generation',
#               'Principal Data Scientist',
#               'Snr. Data Scientist, Market Research',
#               'Senior Data Scientist',
#               'Data Scientist – 51594',
#               'Manager, Research Data Science',
#               'Head of E-Commerce Analytics',
#               'AI/ML Engineer',
#               'Data Scientist, Performance Marketing',
#               'Senior Data Scientist',
#               'Head of Data Science- Health',
#               'Data Scientist (Remote)',
#               'Risk Analyst - Quantitative Modelling & Analysis, RALC (SRS)',
#               'Data Scientist Director',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Data Scientist (Contract) - Statistics',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist',
#               'NLP Data Scientist',
#               'Senior Data Scientist London',
#               'Data Scientist - Predictive Analytics',
#               'Manager, Data and Analytics- Capital Markets, Financial Serv...',
#               'Data Scientist – London',
#               'Data Scientist',
#               'Software Engineer - Machine Learning',
#               'Senior Data Scientist London',
#               'Advisor, Data science and analytics',
#               'Principal Data Scientist',
#               'Global Markets Division - SFL Strats - Associate - London',
#               'Data Scientist – 51594',
#               'Applied Scientist - Deep Learning',
#               'Senior Data Scientist',
#               'Senior Supply Chain Analytics Consultant',
#               'Data Analyst - Rare Diseases',
#               'Data Scientist',
#               'Data & AI Business Analyst',
#               'Data Scientist',
#               'Data Scientist (Multiple Seniorities)',
#               'Advisor, Data science and analytics',
#               'Analytics Engineer',
#               'Data Scientist',
#               'Head of Data Science',
#               'Python Software Engineer - Cloud / Data Science',
#               'Data Science Consultant (FTC)',
#               'Data Scientist',
#               'Artificial Intelligence',
#               'Data Scientist',
#               'Senior Data Scientist (m/f/d)',
#               'Lead Data Scientist',
#               'AI/ML Engineer',
#               'Machine Learning Engineer',
#               'Data Scientist Python - Hedge Fund',
#               'AI & ML DevOps Engineer - Contract',
#               'Data Scientist',
#               'Senior Machine Learning Engineer',
#               'Senior Data Scientist',
#               'Machine Learning Engineer',
#               'Data Science Lead',
#               'Machine Learning Engineer (Remote)',
#               'Lead/ Senior Data Scientist',
#               'Data Analyst, Renewable Energy',
#               'Senior Supply Chain Analytics Consultant',
#               'Data Scientist - Senior Consultant',
#               'Sr. Manager, Data Science',
#               'AI/ML Engineer',
#               'Data Scientist – London',
#               'Data Scientist – Independent Media Agency',
#               'Decision Scientist',
#               'Data Science Analyst, Ascential Marketing Division',
#               'Senior Data Scientist London',
#               'NLP Data Scientist (Mid-Senior Level)',
#               'Python Developer - AI SAAS',
#               'Data Analyst - Rare Diseases',
#               'Advisor, Data science and analytics',
#               'Data Scientist',
#               'Manager, Advanced Data Insight Analytics',
#               'Staff Deep Learning Engineer',
#               'Data Scientist',
#               'Lead Data Scientist',
#               'Data Scientist – 51594',
#               'Data Science Consultant',
#               'Staff Deep Learning Engineer',
#               'Data Scientist',
#               'Lead Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Machine Learning Scientist',
#               'Product Data Analyst',
#               'DATA SCIENTIST',
#               'Head of Data Science',
#               'Specialist, Data Science',
#               'NLP Data Scientist',
#               'Big Data Engineer - Hadoop, Spark, AWS',
#               'Data Science Analyst Fixed Term Contract London',
#               'Statistician',
#               'Natural Language Processing (NLP)',
#               'Part-time Data Scientist',
#               'Data Scientist',
#               'Head of E-Commerce Analytics',
#               'Data Science Consultant',
#               'Big Data Engineer - Hadoop, Spark, AWS',
#               'Data Science Analyst Fixed Term Contract London',
#               'Head of Data Science',
#               'Data Science and Analytics Consultant/Researcher',
#               'AI Solutions Manager, Life Science',
#               'AI Advisory / Data Science Advisory, Senior Manager',
#               'Senior Data Scientist',
#               'Machine Learning Engineer (Contract) - Outside IR35',
#               'Biological Data Science Specialist',
#               'Machine Learning Researcher',
#               'Data Scientist',
#               'Senior Applied Scientist - Traffic & Pricing Platform (w/d/m...',
#               'Sr Data Scientist',
#               'Manager, Data and Analytics- Capital Markets, Financial Serv...',
#               'Machine Learning Engineer - Discover',
#               'Software Engineer, Machine Learning',
#               'Data Science Consultant',
#               'Staff Deep Learning Engineer',
#               'Management Consultant - Supply Chain Analytics',
#               'Machine Learning Engineer',
#               'Advanced Data Insight Analyst III (Marketing Analytics)',
#               'C# Developer: NLP Team',
#               'NLP Data Scientist',
#               'Data Scientist',
#               'Data Science Associate Consultant',
#               'Part Time Faculty for Business Analytics',
#               'Principal Data Scientist',
#               'Senior Audio Machine Learning Engineer',
#               'Marketing Data Scientist',
#               'Data Scientist / AI Engineer',
#               'Staff Machine Learning Research Engineer - Cortex Recommende...',
#               'Senior Data Scientist',
#               'Strategic Consultant - Data Science & Analytics',
#               'Data Science Manager, London',
#               'Machine Learning Engineer',
#               'Data Scientist',
#               'Data Scientist Python - Hedge Fund',
#               'Senior Data Scientist, Insights & Innovation, UK',
#               'Pricing Transformation Big Data Analyst',
#               'Data Scientist, B2B Marketing',
#               'Data Scientist',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Data Scientist',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Machine Learning Platform Engineer',
#               'Junior data science engineer',
#               'Data Science Consultant',
#               'Analyst Healthcare Analytics homebased',
#               'Visual Analytics Consultant',
#               'Data Scientist',
#               'AI Engineer',
#               'Natural Language Processing Engineers',
#               'Head of Data Science',
#               'Data Engineer – Data Science',
#               'Pricing Data Scientist',
#               'Data Scientist - Health Outcomes',
#               'Market Director - Forensic Data Analytics - London',
#               'Data Scientist - Python Developer',
#               'Data Science Lead',
#               'Machine Learning Engineer (Remote)',
#               'Lead/ Senior Data Scientist',
#               'Data Analyst, Renewable Energy',
#               'Senior Data Scientist / ML Engineer',
#               'Data Scientist - Senior Consultant',
#               'Sr. Manager, Data Science',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Senior Strategic Consultant - Data Science & Analytics',
#               'Senior Data Scientist - Global participation',
#               'Senior Data Scientist – London',
#               'Data Scientist',
#               'Data Scientist - NLP Specialist',
#               'BIG DATA ARCHITECT',
#               'Principal Data Scientist, Reinforcement Learning',
#               'Data Scientist (Contract) - Insights',
#               'Principal Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist/ Senior Data Scientist',
#               'Lead/ Senior Data Scientist',
#               'Machine Learning Lead',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Senior Data Scientist, Insights & Innovation, UK',
#               'Principal Applied Scientist',
#               'Senior Applied Scientist - Information Retrieval and Natural...',
#               'Vice President, Advanced Analytics & Prototyping, SpendingPu...',
#               'Data Scientists - Consulting',
#               'Data Analyst, Renewable Energy',
#               'Data Scientist (Geospatial) - Contract',
#               'Data Scientist (NLP) - Inside IR35',
#               'Data Scientist',
#               'Senior Game Data Scientist - Racing',
#               'Head of Data Science',
#               'Engineering Manager - Machine Learning - Health',
#               'AI Architect – London',
#               'Data Lab Architect',
#               'BI Data Manager - Analytics',
#               'Data Scientist',
#               'Data Scientists - Consulting',
#               'Machine Learning Engineer',
#               'Analytics Engineer – Qlik',
#               'Machine Learning Engineer',
#               'Senior Data Scientist - Forecasting',
#               'Senior Data Scientist / Operational Researcher',
#               'AI Architect – London',
#               'Senior Engineer – Machine Learning and Computer Vision',
#               'Applied Scientist - Automated Reasoning',
#               'Senior Data Scientist, Product',
#               'Quantitative Researcher (Data Science/Machine Learning/Mathe...',
#               'Data Science Director',
#               'Lecturer in Climate Physics, Data Science in Climate Energy,...',
#               'Data Scientist',
#               'Senior Applied Scientist - Traffic & Pricing Platform (w/d/m...',
#               'Analytics Engineer – Qlik',
#               'Staff Product Manager - Machine Learning Platform',
#               'LEAD DATA ENGINEER – PYTHON, SQL – DATA SCIENCE – FINANCIAL...',
#               'CIB Investment Bank - Applied AI & Machine Learning - Execut...',
#               'Data Science Leader',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Data Scientist',
#               'Principal Data Scientist - Remote, UK',
#               'Machine Learning Engineer - Kubrick',
#               'Data Scientist',
#               'Data Scientist',
#               'Senior Data Scientist - Badoo',
#               'Senior Data Scientist, Product Analytics',
#               'Machine Learning Scientist Intern',
#               'Computer Vision Deep Learning Engineer',
#               'Senior Data Scientist',
#               'Capital, Control and Operations Big Data Architect',
#               'Natural Language Processing (NLP)',
#               'Applied Scientist - Information Retrieval and Natural Langua...',
#               'Quantitative Researcher (Data Science/Machine Learning/Mathe...',
#               'Database & Data Science Developer',
#               'Data Scientist',
#               'Data Scientist',
#               'Senior Data Architect / Data Scientist - 100% Remote across...',
#               'Senior Data Scientist - 8 MONTH FTC',
#               'Principal Consultant - Analytics Consulting',
#               'Management Consultant – Digital Marketing Analytics',
#               'Lead Data Scientist',
#               'Big Data and Data Science Platforms - Tech lead - FS',
#               'Director, Artificial Intelligence Consulting',
#               'Digital Web Analytics Manager',
#               'Senior Specialist, Data Science',
#               'Associate Director, Digital and Analytics Operations - ICR R...',
#               'Senior Data Scientist',
#               'Pre-Sales Solution Engineer, BI & Analytics',
#               'Analytics Consultant',
#               'Data & Analytics Senior Manager, Digital Pre-school Centre o...',
#               'Research Data Scientist',
#               'Legal Technologist - Machine Learning & Artificial Intellige...',
#               'Head of Data Science',
#               'Pre-Sales Solution Engineer, BI & Analytics',
#               'Head of Data Science',
#               'LEAD DATA ENGINEER – PYTHON, SQL – DATA SCIENCE – FINANCIAL...',
#               'Business Intelligence Engineer - Customer behavior & marketi...',
#               'Lead Data Scientist',
#               'AI Engineer',
#               'Machine Learning Engineer',
#               'Programme Management, Data Science Lead',
#               'Sr Machine Learning Engineer',
#               'Associate Educator, Data Scientist',
#               'Head of Data Science',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Machine Learning Researcher',
#               'Transaction Monitoring Modelling & Analytics',
#               'Algorithm & Software Developer (Machine Learning, Computer V...',
#               'Data Scientist - Machine Learning (Python/SQL)',
#               'Machine Learning Engineer',
#               'Data Scientist Director',
#               'Project Manager, Data & Analytics',
#               'Machine Learning Research Engineer',
#               'Digital Audit Advanced Analytics Senior Associate',
#               'Software Engineer - Machine Learning',
#               'Retail Senior Data Scientist / Retail Data Science Manager',
#               'Machine Learning Team Lead',
#               'Educator, Data Scientist',
#               'Head of Data Science - London - (Cutting Edge NLP!!)',
#               'Senior Data Scientist/ Machine Learning Developer',
#               'Senior Applied Scientist - Information Retrieval and Natural...',
#               'Research Scientist, Natural Language Processing (PhD)',
#               'Senior Data Scientist - UK',
#               'Principal Data Science Consultant',
#               'Machine learning Software Engineer - Senior Associate',
#               'Data Scientist | Python | NLP | London | Contract',
#               'Machine Learning Lead',
#               'AI-Quant - Junior',
#               'Head of Data Science - London - (Cutting Edge NLP!!)',
#               'Senior Data Scientist/ Machine Learning Developer',
#               'Lead Data Scientist',
#               'Data Scientist',
#               'Senior Data Science Engineer',
#               'Senior Data Scientist',
#               'Head of Data Science',
#               'Data Scientist',
#               'Data Scientist (Multiple Seniorities)',
#               'Senior Data Science Engineer',
#               'Machine Learning Engineer',
#               'Data Science Manager - EMEA',
#               'Full Cycle Data Scientist - FinTech',
#               'Machine Learning Engineer',
#               'Machine Learning Engineer',
#               'Analytics Strategy Manager',
#               'Research Data Scientist',
#               'Computer Vision Deep Learning Engineer',
#               'Deep Learning Engineer',
#               'Machine Learning Research Scientist',
#               'Senior Applied Scientist',
#               'Data Scientist - Cancer',
#               'Quantitative Researcher in Natural Language Processing (NLP)',
#               'VP Customer Success @ Leading Machine-Learning SaaS Platform',
#               'Python Developer SQL Machine Learning AWS',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Faculty Data Science & Data Engineering Fellowship (Oct 2021...',
#               'Machine Learning Engineer - Genomic Data',
#               'Technical Product Manager - Data AI Machine Learning',
#               'Analytics Cloud Specialist, EMEA',
#               'NLP Data Scientist',
#               'Product Manager – AI & Machine Learning',
#               'Account Manager @ Machine-Learning Startup',
#               'Product Manager & Data Scientist',
#               'Senior Data Scientist | Search & Rank',
#               'Financial Quant/Data Science - Fintech - London or Paris',
#               'Senior Manager, Customer Analytics',
#               'Data Scientist',
#               'Machine Learning Engineer (Contract) - Outside IR35',
#               'AI Advisory / Data Science Advisory, Senior Manager',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Analytics Strategy Manager',
#               'Digital Web Analytics Manager',
#               'Big Data Engineer',
#               'Analytics Engineer – Qlik',
#               'AI Architect – London',
#               'Machine Learning Research Engineer',
#               'Data Scientist',
#               'Machine Learning Engineer',
#               'Associate Director, Digital and Analytics Operations - ICR R...',
#               'Senior Data Scientist',
#               'Pre-Sales Solution Engineer, BI & Analytics',
#               'Data & Analytics Senior Manager, Digital Pre-school Centre o...',
#               'Senior Data Scientist',
#               'Director – Analytics & AI',
#               'Principal Machine Learning Engineer',
#               'Senior Business Analyst/Data architect',
#               'Big Data Solutions Architect – London',
#               'Financial Crime Analytics Manager',
#               'Site Reliability Engineer - Machine Learning',
#               'Machine Learning Engineer',
#               'Agile Project Manager - Data Analytics',
#               'Data Scientist',
#               'PhD Student, London (AI)',
#               'Data Scientist - Advanced Analytics & Insight',
#               'Lead AI/ML Engineer',
#               'Data Science Team Leader - Robotics',
#               'Lead Data Scientist',
#               'Account Manager, Data Science and Tool Development',
#               'ARTIFICIAL INTELLIGENCE SPECIALIST',
#               'Senior Analytics Translator',
#               'Senior Data Scientist',
#               'AI Success Director',
#               'Head of Data Science - eCommerce',
#               'Lead Data Scientist',
#               'Software Engineer, Machine Learning',
#               'AI/ML Engineer - Production',
#               'Machine Learning Engineer',
#               'Senior Software Engineer (Data Science)',
#               'PSG Business Intelligence & Data Science Manager',
#               'Principal Data Scientist',
#               'Senior Analytics Translator',
#               'Machine Learning Engineer - Golf Start-Up - Python AWS ML Pr...',
#               'Senior Data Scientist',
#               'AI Success Director',
#               'Head of Data Science - eCommerce',
#               'Data Scientist – Insurance',
#               'Lead Data Scientist',
#               'Data Scientist - London',
#               'Data Scientist (Product)',
#               'Software Engineer, Machine Learning',
#               'AI/ML Engineer - Production',
#               'Principal Machine Learning Scientist - Patient Data Analytic...',
#               'Data Scientist',
#               'Data Scientist',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Data Scientist',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Data Scientist - Manager - UKI Assurance - Forensic Data Ana...',
#               'Data Scientist (Geospatial) - Contract',
#               'Senior Game Data Scientist - Racing',
#               'Data Scientist',
#               'Engineering Manager - Machine Learning - Health',
#               'Head of Data Science',
#               'Data Lab Architect',
#               'Data Scientists - Consulting',
#               'Machine Learning Engineer',
#               'Senior Data Scientist - Forecasting',
#               'Database & Data Science Developer',
#               'Market Director - Forensic Data Analytics - London',
#               'Data Scientist - Python Developer',
#               'Apple Media Products (AMP)- Big Data Engineer - Core Marketi...',
#               'Software Engineer, Machine Learning & Program Analysis',
#               'Head Of Data & Analytics',
#               'Data Scientist',
#               'Senior Software Engineer, AI/ML Production',
#               'Partner Engineer - Network Analytics',
#               'Senior Machine Learning Research Engineer',
#               'Computer Vision Engineer, Deep Learning',
#               'Junior Data Science Consultant',
#               'Senior Data Scientist',
#               'Deep Learning Scientist',
#               'Professor in Computer Vision and Machine Learning',
#               'Data Analytics Lead',
#               'Data Scientist Python PhD',
#               'Data Science Lecturer',
#               'Principal Machine Learning Engineer',
#               'Senior Consultant, Medallia Strategy Analytics',
#               'Deep Learning Engineer',
#               'Principal Machine Learning Engineer REMOTE',
#               'Senior Software Engineer (Data Science)',
#               'Senior Data Scientist',
#               'Audience Measurement - Data Science Product Manager',
#               'Senior Statistician, Data Science',
#               'Technical Product Manager (Machine Learning)',
#               'Senior Data Scientist',
#               'Computer Vision Machine Learning Engineer',
#               'Machine Learning Research Engineer',
#               'Pre-sales Solutions Architect - Data & AI',
#               'Data Scientist',
#               'Senior NLP Researcher',
#               'Software Engineer - Data/Machine Learning - £550/650pd',
#               'Financial Crime Analytics Manager',
#               'Audio Machine Learning Data Engineer',
#               'BI Data Manager - Analytics',
#               'Professor in Computer Vision and Machine Learning',
#               'Deep Learning Engineer',
#               'Big Data Engineer - Hadoop, Spark, Cloud',
#               'Principal Scientist - Patient Data Analytics',
#               'AI Success Director',
#               'Adobe Analytics Lead',
#               'Data Scientist',
#               'Analytics Manager London',
#               'Data Science Content Developer',
#               'Algorithm & Software Developer (Machine Learning, Computer V...',
#               'Machine Learning Engineer (Two way recommender systems)',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Data Scientist',
#               'FINANCE ANALYTICS MANAGER, PROPERTY & CASUALTY',
#               'Senior Data Scientist',
#               'Senior Data Scientist',
#               'Legal Technologist - Machine Learning & Artificial Intellige...',
#               'Senior AI/ML Engineer - Sequence Learning',
#               'Python Engineer Machine Learning SQL',
#               'Digital Analytics Manager London, United Kingdom Consumer',
#               'Senior Data Scientist',
#               'Statistical Programmer I (SAS or R) – Real World Evidence (o...',
#               'Quantitative Researcher in Natural Language Processing (NLP)',
#               'VP Customer Success @ Leading Machine-Learning SaaS Platform',
#               'SENIOR DATA SCIENTIST',
#               'Python Developer SQL Machine Learning AWS',
#               'Senior Data Scientist',
#               'Senior Applied Research Scientist, NLP',
#               'Senior Machine Learning Engineer',
#               'Machine Learning Engineer',
#               'Digital Analytics Manager',
#               'Director of Applied Data Science',
#               'Senior Machine Learning Research Engineer',
#               'Director, Data Science',
#               'Senior Biostatistician (FSP) Home Based',
#               'Apple Media Products (AMP)- Big Data Engineer - Core Marketi...',
#               'Data Scientist',
#               'Data Scientist',
#               'Consulting Project Manager Analytics & Clinical Services',
#               'Director - Analytics & AI',
#               'Data Science Team Leader - Robotics',
#               'Principal Data Science Consultant',
#               'Machine Learning (Contract) - Outside IR35',
#               'Machine Learning Research Engineer',
#               'Staff Machine Learning Engineer',
#               'Machine Learning Engineer III',
#               'Senior Bioinformatics Data Scientist',
#               'Principal Machine Learning Engineer',
#               'Senior Data Science Engineer',
#               'Data Scientist',
#               'Product Manager (Data Science)',
#               'Big Data Lead',
#               'Senior Data Scientist',
#               'Data Scientist',
#               'Data Science – Recruitment Consultant – City of London',
#               'NLP Developer/ML Engineer',
#               'FINANCE ANALYTICS MANAGER, PROPERTY & CASUALTY',
#               'Lead Data Engineer - AI Consultancy - London',
#               'Lead NLP Data Scientist',
#               'Senior Consultant, Advanced Analytics (Remote)',
#               'Head of Data Science',
#               'Machine Learning Engineer',
#               'Real World Data Senior Biostatistician',
#               'Data Science Consultant - Software Product',
#               'Data Scientist',
#               'Senior Research Data Scientist',
#               'Machine Learning Developer',
#               'Senior Manager Data and Analytics',
#               'Data Scientist/ Senior Data Scientist',
#               'Lead Machine Learning Teacher',
#               'Genomics Data Scientist',
#               'Cancer Genomics Data Scientist',
#               'Big Data Engineering Lead',
#               'Head of Data Science',
#               'Data Scientist - Government',
#               'AI-Quant - Intermediate',
#               'Machine Learning Software Engineer',
#               'Machine Learning Engineer - Trading',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - ML/NLP',
#               'NLP Data Scientist',
#               'Lead Data Science Consultant',
#               'Data Scientist',
#               'Senior Advisor, Data science and Analytics',
#               'Senior Machine Learning Engineer',
#               'Senior Data Scientist - Forecasting',
#               'Software Engineer (AI / ML)',
#               'Robotics Research Engineer - Machine Learning',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'NLP Data Scientist',
#               'Big Data DevOps Engineer',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Senior Machine Learning Engineer - Leading Data/ AI Consulta...',
#               'Senior Product Manager (Data Science/ AI)',
#               'AI Success Director (Spanish Language Requirements)',
#               'Product Manager (Data Science)',
#               'Senior Analytics Engineer- DBT',
#               'Senior Machine Learning Engineer',
#               'Principal Biostatistician',
#               'Software Engineer, AR Machine Learning',
#               'Senior Data Scientist',
#               'Customer-Facing Data Scientists - London',
#               'Senior Data Scientist',
#               '1774- Sr. Director, Analytics and Modeling',
#               'Senior Software Engineer (Python), AI/Machine Learning - Lon...',
#               'Data Scientist (Growth Tribe)',
#               'Director, Patient Services Analytics and Insights',
#               'Senior Data Scientist',
#               '1774- Sr. Director, Analytics and Modeling',
#               'Senior Software Engineer (Python), AI/Machine Learning - Lon...',
#               'Data Scientist (Growth Tribe)',
#               'Director, Patient Services Analytics and Insights',
#               'Machine Learning/Computer Vision Scientist (Home W',
#               'Digital Analytics Manager',
#               'Pre-Sales Solution Engineer, BI & Analytics, Tableau',
#               'Data Science Manager',
#               'Lead Machine Learning Scientist',
#               'NLP Data Scientist',
#               'Applied Machine Learning Scientist',
#               'Senior Data Science Consultant',
#               'ARTIFICIAL INTELLIGENCE & ALGORITHM PRO',
#               'Senior Machine Learning Engineer',
#               'Senior Bioinformatics Data Scientist',
#               'Polyglot Engineer (AI Start-Up) - Python/ Golang/ Javascript',
#               'Performance Analytics Manager',
#               'Manager, Global Analytics Platform',
#               'C++ Developer - Risk, Machine Learning - London',
#               'Machine Learning Engineer; Computer Vision, Data S',
#               'Lead Engineer - Python - Machine Learning',
#               'Senior Lead Analyst - Analytics Technology',
#               'Lead Data Scientist',
#               'Principal Statistician',
#               'Senior Machine Learning Scientist - DeepTech Startup (AgriTe...',
#               'Senior Machine Learning Engineer',
#               'Principal Data Scientist (Supply)',
#               'Data Scientist',
#               'Product Analytics Manager',
#               'Principal Biostatistician (FSP) Home Based',
#               'MACHINE LEARNING SPECIALIST',
#               'Quantitative Financial Modeller – Balance Sheet & Analytics',
#               'Data Analytics Manager – Telecommunications',
#               'Senior AI/ML Engineer',
#               'Senior Biostatistician (FSP) Home Based',
#               'Technical Coach: Data Science',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Machine Learning Engineer',
#               'Senior Business Intelligence Consultant – CRM Analytics',
#               'Head of Analytics',
#               'Senior Machine Learning Engineer',
#               'Recruitment Consultant - Data Science',
#               'Lead Data Scientist / R&D Engineer',
#               'Senior Analyst/Developer, Pricing Analytics & Models (PAM) &...',
#               'Product Manager | AI',
#               'Senior Data Science Engineer',
#               'Senior ML Engineer',
#               'Technical BA - Analytics & Automation',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior Software Engineer - Machine Learning',
#               'Machine Learning Engineer',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Software Engineer (AI / ML)',
#               'Senior Product Manager, Database Capabilities (Graph & Time...',
#               'Senior Statistician',
#               'Data Analytics Manager – Telecommunications',
#               'Director, Patient Services Analytics and Insights',
#               'Senior Machine Learning Engineer',
#               'Product Manager | AI',
#               'Senior Data Science Engineer',
#               'Senior ML Engineer',
#               'Machine Learning Ops Engineer',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior ML Engineer (contract)',
#               'Data Scientist',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Principal Data Scientist - Remote, UK',
#               'Data Scientist',
#               'Senior Machine Learning Scientist',
#               'Senior Data Scientist',
#               'Business Analyst - Analytics',
#               'Analytics Cloud Specialist, EMEA',
#               'BIG DATA ARCHITECT',
#               'Principal Consultant - Analytics Consulting',
#               'Solution Architect - Technical Presales (Big Data, Analytics...',
#               'Pre-sales Solutions Architect - Data & AI - Retail or CPG',
#               'Machine Learning Engineer',
#               'Product Analytics Manager',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Database & Data Science Developer',
#               'Data Scientist',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Software Engineer - Machine Learning',
#               'Senior Machine Learning Engineer',
#               'Senior Linux/DevOps Engineer with focus on Big Data',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Senior Product Manager, Database Capabilities (Graph & Time...',
#               'Robotics Research Engineer - Machine Learning',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Econometric Analyst - Machine Learning',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Technical BA - Analytics & Automation',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Big Data DevOps Engineer',
#               'Senior Technical Product Manager, AI & Machine Learning, Rea...',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Data Scientist',
#               'Data Scientist',
#               'Applied Computer Vision Scientist / Senior Developer',
#               'Data Scientist - Health Outcomes',
#               'Data Scientist',
#               'Machine Learning Engineer - Kubrick',
#               'Data Scientist',
#               'Senior Data Scientist',
#               'Apple Media Products (AMP)- Big Data Engineer - Core Marketi...',
#               'Data Scientist',
#               'Data Scientist',
#               'Partner Engineer - Network Analytics',
#               'Senior Data Scientist',
#               'Data Engineer – Specialty Analytics',
#               'Data Science Manager',
#               'Analytics Consultant',
#               'Market Director - Forensic Data Analytics - London',
#               'Data Scientist - Python Developer',
#               'Machine Learning Platform Engineer',
#               'Principle Data Scientist',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'Senior Software Engineer (Data Science)',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Research Data Scientist',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Machine Learning Engineer',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Linux/DevOps Engineer with focus on Big Data',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Technical BA - Analytics & Automation',
#               'Senior Machine Learning Engineer',
#               'Senior Software Engineer - Data Science',
#               'NLP Data Scientist',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Senior Product Manager, Database Capabilities (Graph & Time...',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior Software Engineer - Machine Learning',
#               'Product Manager | AI',
#               'Senior Machine Learning Engineer',
#               'NLP Data Scientist',
#               'Senior Software Engineer - Data Science',
#               'Technical BA - Analytics & Automation',
#               'Big Data DevOps Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
#               'Robotics Research Engineer - Machine Learning',
#               'Senior Software Engineer - Machine Learning',
#               'Senior Software Engineer - Data Science',
#               'Senior Computer Vision / Machine Learning Engineer',
#               'Senior ML Engineer (contract)',
#               'Senior Machine Learning Engineer',
#               'Risk Analytics - Senior Manager - Connected Technology',
#               'Senior Linux/DevOps Engineer with focus on Big Data',
#               'Senior Machine Learning Engineer - Consumer Business Unit',
#               'Senior NLP / Computational Linguist Engineer (Information Ex...',
#               'Senior Machine Learning Engineer',
#               'Big Data DevOps Engineer',
#               'Senior Machine Learning Engineer - Autonomous Driving - Lond...',
#               'Technical BA - Analytics & Automation',
#               'Senior Data Engineer (Machine Learning & AI use cases)',
# ...
#               nan,
#               nan,
#               '£59688 - £67767 a year',
#               '£40000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               '£85000 - £95000 a year',
#               nan,
#               nan,
#               '£53000 a year',
#               nan,
#               '£40000 - £50000 a year',
#               nan,
#               '£32000 a year',
#               '£35000 - £45000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £80000 a year',
#               '£80000 - £110000 a year',
#               '£60000 - £65000 a year',
#               nan,
#               nan,
#               '£95000 a year',
#               '£70000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£40000 - £50000 a year',
#               nan,
#               '£50000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£85000 - £95000 a year',
#               nan,
#               '£80000 - £100000 a year',
#               nan,
#               '£390 - £425 a day',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£55000 - £75000 a year',
#               nan,
#               '£70000 - £100000 a year',
#               '£32000 a year',
#               '£90000 - £110000 a year',
#               nan,
#               '£34000 - £38000 a year',
#               nan,
#               nan,
#               '£68139 - £75710 a year',
#               nan,
#               nan,
#               '£120000 - £130000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£500 - £600 a day',
#               '£75000 - £100000 a year',
#               nan,
#               '£120000 - £130000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£65000 - £70000 a year',
#               nan,
#               '£40000 - £55000 a year',
#               '£40000 - £110000 a year',
#               nan,
#               '£70000 - £90000 a year',
#               nan,
#               '£80000 - £120000 a year',
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               '£40000 - £65000 a year',
#               nan,
#               '£60000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£80000 - £95000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£75000 a year',
#               '£500 - £550 a day',
#               '£110000 - £130000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£75000 - £95000 a year',
#               nan,
#               nan,
#               '£32000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£90000 a year',
#               '£65000 - £75000 a year',
#               nan,
#               nan,
#               '£65000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£80000 - £95000 a year',
#               nan,
#               '£60000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               '£40000 - £45000 a year',
#               '£70000 a year',
#               nan,
#               '£50000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£35000 - £45000 a year',
#               '£53000 a year',
#               nan,
#               '£32000 a year',
#               '£40000 - £50000 a year',
#               nan,
#               nan,
#               '£450 - £500 a day',
#               nan,
#               nan,
#               nan,
#               '£110000 - £120000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£350 - £400 a day',
#               nan,
#               nan,
#               nan,
#               '£50000 - £62000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£40000 - £50000 a year',
#               nan,
#               '£80000 - £85000 a year',
#               nan,
#               nan,
#               '£65000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               '£70000 - £100000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£65000 a year',
#               nan,
#               '£55000 - £75000 a year',
#               '£60000 - £70000 a year',
#               '£70000 a year',
#               nan,
#               nan,
#               nan,
#               '£550 - £650 a day',
#               '£65000 - £75000 a year',
#               nan,
#               '£570 a day',
#               nan,
#               '£60000 a year',
#               '£90000 - £120000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£75000 - £85000 a year',
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£55000 - £65000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               '£60000 - £80000 a year',
#               nan,
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£550 - £650 a day',
#               '£70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £100000 a year',
#               '£60000 - £90000 a year',
#               '£80000 - £95000 a year',
#               nan,
#               nan,
#               '£37000 a year',
#               nan,
#               nan,
#               nan,
#               '£75000 - £95000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£55000 - £75000 a year',
#               '£50000 - £60000 a year',
#               '£60000 a year',
#               nan,
#               '£50000 - £100000 a year',
#               '£85000 - £100000 a year',
#               nan,
#               nan,
#               '£100000 a year',
#               nan,
#               nan,
#               nan,
#               '£40000 - £50000 a year',
#               '£65000 - £75000 a year',
#               '£85000 - £100000 a year',
#               nan,
#               nan,
#               '£85000 - £100000 a year',
#               nan,
#               nan,
#               '£60000 - £80000 a year',
#               '£65000 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               nan,
#               '£60000 - £90000 a year',
#               '£70000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               '£60000 - £75000 a year',
#               '£40000 - £70000 a year',
#               nan,
#               nan,
#               '£70000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £90000 a year',
#               nan,
#               nan,
#               '£35000 - £40000 a year',
#               '£50000 - £60000 a year',
#               nan,
#               '£60000 - £90000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £86000 a year',
#               '£35000 - £45000 a year',
#               nan,
#               '£90000 a year',
#               '£30000 - £55000 a year',
#               '£75000 - £95000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               '£65000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£60000 - £70000 a year',
#               nan,
#               '£40000 - £45000 a year',
#               nan,
#               nan,
#               '£25000 - £35000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £45000 a year',
#               '£53000 a year',
#               nan,
#               '£32000 a year',
#               nan,
#               '£40000 - £50000 a year',
#               '£100000 - £120000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£28000 - £35000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£35000 - £45000 a year',
#               nan,
#               nan,
#               '£53000 a year',
#               '£40000 - £50000 a year',
#               '£32000 a year',
#               nan,
#               nan,
#               nan,
#               '£45000 a year',
#               '£50000 - £55000 a year',
#               nan,
#               '£85000 - £100000 a year',
#               '£60000 - £80000 a year',
#               nan,
#               nan,
#               nan,
#               '£350 - £400 a day',
#               '£40000 - £65000 a year',
#               '£50000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               '£50000 - £55000 a year',
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£70000 - £75000 a year',
#               nan,
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               nan,
#               '£35000 - £55000 a year',
#               nan,
#               nan,
#               '£52500 - £85000 a year',
#               nan,
#               nan,
#               '£45000 - £60000 a year',
#               '£60000 - £70000 a year',
#               ...]})

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE
jobs_all = pd.DataFrame(results, columns = ['title', 'company', 'location', 'salary'])

# %%
jobs_all.shape
# Out:
# (10690, 4)

# %% [markdown]
# Lastly, we need to clean up salary data.
#
# 1. Only a small number of the scraped results have salary information - only these will be used for modeling.
# 1. Some of the salaries are not yearly but hourly or weekly, these will not be useful to us for now.
# 1. Some of the entries may be duplicated.
# 1. The salaries are given as text and usually with ranges.

# %% [markdown]
# #### Find the entries with annual salary entries, by filtering the entries without salaries or salaries that are not yearly (filter those that refer to hour or week). Also, remove duplicate entries.

# %%
## YOUR CODE HERE
jobs = jobs_all.drop_duplicates()
jobs.dropna(inplace=True)
jobs = jobs[jobs.salary.str.contains('year')]
jobs.reset_index(drop=True, inplace=True)
jobs
# Out:
# <ipython-input-22-73349ab76d6b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobs.dropna(inplace=True)
#                                          title  \
# 0                               Data Scientist
# 1                               Data Scientist
# 2    VelocITy Data & AI Graduate Programme, UK
# 3                               Data Scientist
# 4                               Data Scientist
# ..                                         ...
# 138                             Data Scientist
# 139                      Senior Data Scientist
# 140        Data Engineer – Specialty Analytics
# 141          Product Manager - Computer Vision
# 142                             Data Scientist
#
#                                 company         location  \
# 0    London Ambulance Service NHS Trust   London SE1 8SD
# 1                 Public Health England    Colindale NW9
# 2                               Avanade           London
# 3              Ambassador Theatre Group           London
# 4                            Datasource           London
# ..                                  ...              ...
# 138                           Movement8           London
# 139                 Metrica Recruitment           London
# 140             Data Science Works, Inc           London
# 141                             Harnham           London
# 142                      Sykes Cottages  Chester CH1 3BQ
#
#                       salary
# 0     £45780 - £51393 a year
# 1     £32331 - £39691 a year
# 2              £30000 a year
# 3              £45000 a year
# 4     £30000 - £50000 a year
# ..                       ...
# 138   £50000 - £55000 a year
# 139  £85000 - £100000 a year
# 140   £60000 - £80000 a year
# 141   £60000 - £65000 a year
# 142   £40000 - £50000 a year
#
# [143 rows x 4 columns]

# %%
jobs.location.unique()
# Out:
# array(['London SE1 8SD', 'Colindale NW9', 'London', 'London SE1 1JD',
#        'Croydon', 'South Kensington', 'London EC1V', 'Soho W1F 8BH',
#        'London NW1 7JR', 'London SW15 1RT', 'Dartford DA1 5GA',
#        'London E1 8QS', 'Reigate', 'London W1D 3QG', 'London W10 5JJ',
#        'Chertsey', 'Chester CH1 3BQ'], dtype=object)

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary.

# %%
import re

def salary_formatter(sal):
    split = re.findall(r'[0-9]+', sal)
    if len(split)>1:
        return sum([float(val) for val in split])/len(split)
    return float(split[0])

salary_formatter('$114700 - £120000 a year')
# Out:
# 117350.0

# %%
jobs.salary = jobs.salary.apply(salary_formatter)

# %%
jobs
# Out:
#                                          title  \
# 0                               Data Scientist
# 1                               Data Scientist
# 2    VelocITy Data & AI Graduate Programme, UK
# 3                               Data Scientist
# 4                               Data Scientist
# ..                                         ...
# 138                             Data Scientist
# 139                      Senior Data Scientist
# 140        Data Engineer – Specialty Analytics
# 141          Product Manager - Computer Vision
# 142                             Data Scientist
#
#                                 company         location   salary
# 0    London Ambulance Service NHS Trust   London SE1 8SD  48586.5
# 1                 Public Health England    Colindale NW9  36011.0
# 2                               Avanade           London  30000.0
# 3              Ambassador Theatre Group           London  45000.0
# 4                            Datasource           London  40000.0
# ..                                  ...              ...      ...
# 138                           Movement8           London  52500.0
# 139                 Metrica Recruitment           London  92500.0
# 140             Data Science Works, Inc           London  70000.0
# 141                             Harnham           London  62500.0
# 142                      Sykes Cottages  Chester CH1 3BQ  45000.0
#
# [143 rows x 4 columns]

# %% [markdown]
# ### Save your results as a CSV

# %%
jobsdb = pd.read_csv('../jobs.csv')
jobsdb.reset_index(drop=True)
jobs.reset_index(drop=True)
jobs_new = pd.concat([jobsdb, jobs], axis=0)
jobs_new.drop(['Unnamed: 0'], axis=1, inplace=True)
jobs_new.drop_duplicates(inplace=True)
jobs_new.to_csv(path_or_buf='../jobs.csv')

# %% [markdown]
# ### Load in the data of scraped salaries

# %%
jobs = pd.read_csv('../jobs.csv')
jobs.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
jobs
# Out:
#                                                  title  \
# 0                                       data scientist
# 1    city research scientist i / data analyst, bure...
# 2            data scientist - nationwide opportunities
# 3    city research scientist i / data and technolog...
# 4                  senior etl developer & data analyst
# ..                                                 ...
# 476  Senior Linux/DevOps Engineer with focus on Big...
# 477                                     Data Scientist
# 478                              Senior Data Scientist
# 479                Data Engineer – Specialty Analytics
# 480                  Product Manager - Computer Vision
#
#                            company            location    salary  \
# 0                  fire department  brooklyn, ny 11201   97735.5
# 1    dept of health/mental hygiene    queens, ny 11101   67347.0
# 2        amazon web services, inc.        new york, ny  114700.0
# 3    dept of health/mental hygiene    queens, ny 11101   67347.0
# 4      hra/dept of social services        brooklyn, ny  101500.0
# ..                             ...                 ...       ...
# 476                  Linux Recruit              London   72500.0
# 477                      Movement8              London   52500.0
# 478            Metrica Recruitment              London   92500.0
# 479        Data Science Works, Inc              London   70000.0
# 480                        Harnham              London   62500.0
#
#     median_high_low country
# 0              high     usa
# 1               low     usa
# 2              high     usa
# 3               low     usa
# 4              high     usa
# ..              ...     ...
# 476             NaN     NaN
# 477             NaN     NaN
# 478             NaN     NaN
# 479             NaN     NaN
# 480             NaN     NaN
#
# [481 rows x 6 columns]

# %%
from forex_python.converter import CurrencyRates

# %%
currency = CurrencyRates()

# %%
currency.get_rate('GBP', 'USD')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~/opt/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f9cc446ea60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='api.ratesapi.io', port=443): Max retries exceeded with url: /api/latest?base=GBP&symbols=USD&rtype=fpy (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9cc446ea60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-185-cd8811c73056> in <module>
# ----> 1 currency.get_rate('GBP', 'USD')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/forex_python/converter.py in get_rate(self, base_cur, dest_cur, date_obj)
#      64         payload = {'base': base_cur, 'symbols': dest_cur, 'rtype': 'fpy'}
#      65         source_url = self._source_url() + date_str
# ---> 66         response = requests.get(source_url, params=payload)
#      67         if response.status_code == 200:
#      68             rate = self._get_decoded_rate(response, dest_cur)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.ratesapi.io', port=443): Max retries exceeded with url: /api/latest?base=GBP&symbols=USD&rtype=fpy (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9cc446ea60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# # MAY NOT WORK, MAY HAVE TO JUST USE THE CURRENCY CONVERSIONS ON THE DAY OF HAND IN

# %%
jobs.shape
# Out:
# (329, 4)

# %%
## YOUR CODE HERE

# %% [markdown]
# ### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median).
#
# We could also perform Linear Regression (or any regression) to predict the salary value here. Instead, we are going to convert this into a _binary_ classification problem, by predicting two classes, HIGH vs LOW salary.
#
# While performing regression may be better, performing classification may help remove some of the noise of the extreme salaries. We don't have to choose the `median` as the splitting point - we could also split on the 75th percentile or any other reasonable breaking point.
#
# In fact, the ideal scenario may be to predict many levels of salaries.

# %%
median = jobs.salary.median()

def hi_or_lo(salary):
    if salary < median:
        return 'Low'
    return 'High'

# %%
## YOUR CODE HERE

jobs['median_high_low'] = jobs.salary.apply(hi_or_lo)

# %%
jobs
# Out:
#                                                  title  \
# 0                                       data scientist
# 1    city research scientist i / data analyst, bure...
# 2            data scientist - nationwide opportunities
# 3    city research scientist i / data and technolog...
# 4                  senior etl developer & data analyst
# ..                                                 ...
# 324  senior data engineer (machine learning & ai us...
# 325  senior linux/devops engineer with focus on big...
# 326                              senior data scientist
# 327                   senior digital analytics manager
# 328  polyglot engineer (ai start-up) - python/ gola...
#
#                              company            location    salary  \
# 0                    fire department  brooklyn, ny 11201   97735.5
# 1      dept of health/mental hygiene    queens, ny 11101   67347.0
# 2          amazon web services, inc.        new york, ny  114700.0
# 3      dept of health/mental hygiene    queens, ny 11101   67347.0
# 4        hra/dept of social services        brooklyn, ny  101500.0
# ..                               ...                 ...       ...
# 324                nuvola resourcing            chertsey   65000.0
# 325                    linux recruit              london   72500.0
# 326                        consortia              london   85000.0
# 327          digital republic talent              london   77500.0
# 328  gcs recruitment specialists ltd              london   65500.0
#
#     median_high_low  country
# 0              high      usa
# 1               low      usa
# 2              high      usa
# 3               low      usa
# 4              high      usa
# ..              ...      ...
# 324             low  england
# 325             low  england
# 326            high  england
# 327             low  england
# 328             low  england
#
# [329 rows x 6 columns]

# %%
from geopy import Nominatim

# %%
jobs[:148].country = 'usa'

# %%
def geo_loc(loc):
    try:
        geolocation = Nominatim(user_agent="app").geocode(loc)
        return geolocation.longitude, geolocation.latitude
    except:
        return np.nan

# %%
def geo_lon(loc):
    try:
        geolocation = Nominatim(user_agent="app").geocode(loc)
        return geolocation.longitude
    except:
        return np.nan

# %%
def geo_lat(loc):
    try:
        geolocation = Nominatim(user_agent="app").geocode(loc)
        return geolocation.latitude
    except:
        return np.nan

# %%
jobs_test = jobs.copy()

# %%
jobs_test['geo'] = jobs_test.location.apply(geo_loc)
jobs_test['longitude'] = jobs_test.location.apply(geo_lon)
jobs_test['latitude'] = jobs_test.location.apply(geo_lat)

# %%
jobs_test.isnull().sum()
jobs_test.dropna(inplace=True)

# %%
geo_loc('brooklyn, ny 11201')
# Out:
# (-73.9495823, 40.6501038)

# %% [markdown]
# #### Thought experiment: What is the baseline accuracy for this model?

# %%
## YOUR CODE HERE

jobs.median_high_low.value_counts(normalize=True)
# Out:
# high    0.525836
# low     0.474164
# Name: median_high_low, dtype: float64

# %%
print(f'baseline score is {round(jobs.median_high_low.value_counts(normalize=True)[0], 4)}')
# Out:
# baseline score is 0.5258

# %% [markdown]
# <!--     The baseline accuracy for the model is 0.538. -->

# %% [markdown]
# ### Create a classification model to predict High/Low salary.
#
#
# - Start by ONLY using the location as a feature.
# - Use at least two different classifiers you find suitable.
# - Remember that scaling your features might be necessary.
# - Display the coefficients/feature importances and write a short summary of what they mean.
# - Create a few new variables in your dataframe to represent interesting features of a job title (e.g. whether 'Senior' or 'Manager' is in the title).
# - Incorporate other text features from the title or summary that you believe will predict the salary.
# - Then build new classification models including also those features. Do they add any value?
# - Tune your models by testing parameter ranges, regularization strengths, etc. Discuss how that affects your models.
# - Discuss model coefficients or feature importances as applicable.

# %%
from geopy.geocoders import Nominatim

# %%
def lower(string):
    if type(string)==str:
        return string.lower()
    return string

jobs = jobs.applymap(lower)

# %%
jobs
# Out:
#                                                  title  \
# 0                                       data scientist
# 1    city research scientist i / data analyst, bure...
# 2            data scientist - nationwide opportunities
# 3    city research scientist i / data and technolog...
# 4                  senior etl developer & data analyst
# ..                                                 ...
# 324  senior data engineer (machine learning & ai us...
# 325  senior linux/devops engineer with focus on big...
# 326                              senior data scientist
# 327                   senior digital analytics manager
# 328  polyglot engineer (ai start-up) - python/ gola...
#
#                              company            location    salary  \
# 0                    fire department  brooklyn, ny 11201   97735.5
# 1      dept of health/mental hygiene    queens, ny 11101   67347.0
# 2          amazon web services, inc.        new york, ny  114700.0
# 3      dept of health/mental hygiene    queens, ny 11101   67347.0
# 4        hra/dept of social services        brooklyn, ny  101500.0
# ..                               ...                 ...       ...
# 324                nuvola resourcing            chertsey   65000.0
# 325                    linux recruit              london   72500.0
# 326                        consortia              london   85000.0
# 327          digital republic talent              london   77500.0
# 328  gcs recruitment specialists ltd              london   65500.0
#
#     median_high_low
# 0              high
# 1               low
# 2              high
# 3               low
# 4              high
# ..              ...
# 324             low
# 325             low
# 326            high
# 327             low
# 328             low
#
# [329 rows x 5 columns]

# %%
pd.DataFrame(pd.DataFrame(jobs.company.unique()).sort_values(by=0))[0].unique()

# %%
## YOUR CODE HERE

# def key_words(title):
#     

def title_cleaner(title):
    return title.replace('sr.', 'senior').replace('sr', 'senior')

def senior(title):
    if ('senior' in title) or ('sr' in title):
        return 1
    return 0

def manager(title):
    if 'manag' in title:
        return 1
    return 0

def lead(title):
    if 'lead' in title:
        return 1
    return 0

['senior', 'manager', 'lead']
# Out:
# ['senior', 'manager', 'lead']

# %%
jobs.title = jobs.title.apply(title_cleaner)
# jobs['senior'] = jobs['title'].apply(senior)
# jobs['manager'] = jobs['title'].apply(manager)
# jobs['lead'] = jobs['title'].apply(lead)

# %%
jobs
# Out:
#                                                  title  \
# 0                                       data scientist
# 1    city research scientist i / data analyst, bure...
# 2            data scientist - nationwide opportunities
# 3    city research scientist i / data and technolog...
# 4                  senior etl developer & data analyst
# ..                                                 ...
# 324  senior data engineer (machine learning & ai us...
# 325  senior linux/devops engineer with focus on big...
# 326                              senior data scientist
# 327                   senior digital analytics manager
# 328  polyglot engineer (ai start-up) - python/ gola...
#
#                              company            location    salary  \
# 0                    fire department  brooklyn, ny 11201   97735.5
# 1      dept of health/mental hygiene    queens, ny 11101   67347.0
# 2          amazon web services, inc.        new york, ny  114700.0
# 3      dept of health/mental hygiene    queens, ny 11101   67347.0
# 4        hra/dept of social services        brooklyn, ny  101500.0
# ..                               ...                 ...       ...
# 324                nuvola resourcing            chertsey   65000.0
# 325                    linux recruit              london   72500.0
# 326                        consortia              london   85000.0
# 327          digital republic talent              london   77500.0
# 328  gcs recruitment specialists ltd              london   65500.0
#
#     median_high_low
# 0              high
# 1               low
# 2              high
# 3               low
# 4              high
# ..              ...
# 324             low
# 325             low
# 326            high
# 327             low
# 328             low
#
# [329 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### For the models, I will try both voting and stacking ensemble methods. A RandomForestClassifier will be used as well as LogisticRegression with a GradientBoostClassifier

# %% [markdown]
# #### Test using the longitude and latitude extracted by geopy's Nominatim

# %% [markdown]
# ##### set up the X, y and train-test sets

# %%
y = jobs_test['median_high_low']

# %%
X = jobs_test[['longitude', 'latitude']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %% [markdown]
# ##### decision tree classifier

# %%
dtc_ll = DecisionTreeClassifier().fit(X_train, y_train)

# %%
dtc_ll.score(X_train, y_train)
# Out:
# 0.8523206751054853

# %%
dtc_ll.score(X_test, y_test)
# Out:
# 0.7833333333333333

# %%
dtc_ll.feature_importances_
# Out:
# array([0.19166239, 0.80833761])

# %% [markdown]
# ##### logistic regression

# %%
log_ll = LogisticRegression().fit(X_train, y_train)

# %%
log_ll.score(X_train, y_train)
# Out:
# 0.7805907172995781

# %%
log_ll.score(X_test, y_test)
# Out:
# 0.8166666666666667

# %% [markdown]
# #### Test using the location variable, countvectorized to find commonalities

# %% [markdown]
# ##### set up the X, y and train-test sets

# %%
y = jobs['median_high_low']

# %%
X = jobs[['location']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %% [markdown]
# ##### pipeline with a decision tree classifier

# %%
cvec_location = CountVectorizer(stop_words='english', max_df=0.9, min_df=1)
dtc_loc = DecisionTreeClassifier()

# %%
col_trans = ColumnTransformer([('location', cvec_location, 'location')], remainder='passthrough')

# %%
pipe_loc_dtc = make_pipeline(col_trans, dtc_loc)

# %%
pipe_loc_dtc.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('location',
#                                                   CountVectorizer(max_df=0.9,
#                                                                   stop_words='english'),
#                                                   'location')])),
#                 ('decisiontreeclassifier', DecisionTreeClassifier())])

# %%
pipe_loc_dtc.score(X_train, y_train)
# Out:
# 0.8745247148288974

# %%
pipe_loc_dtc.score(X_test, y_test)
# Out:
# 0.7272727272727273

# %% [markdown]
# ##### pipeline with a logistic regression model

# %%
log_loc = LogisticRegression()

# %%
pipe_loc_log = make_pipeline(col_trans, log_loc)

# %%
pipe_loc_log.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('location',
#                                                   CountVectorizer(max_df=0.9,
#                                                                   stop_words='english'),
#                                                   'location')])),
#                 ('logisticregression', LogisticRegression())])

# %%
pipe_loc_log.score(X_train, y_train)
# Out:
# 0.844106463878327

# %%
pipe_loc_log.score(X_test, y_test)
# Out:
# 0.7272727272727273

# %%
feature_columns = pipe_loc_log['columntransformer'].get_feature_names()

# %%
feature_columns[:5]
# Out:
# ['location__10118',
#  'location__11101',
#  'location__11201',
#  'location__12206',
#  'location__1jd']

# %%
len('location__')
# Out:
# 10

# %%
feature_names = [col[len('location__'):] for col in feature_columns]

# %%
feature_names
# Out:
# ['10118',
#  '11101',
#  '11201',
#  '12206',
#  '1jd',
#  '30030',
#  '30071',
#  '30308',
#  '30324',
#  '30326',
#  '30350',
#  '3qg',
#  '5jj',
#  '60601',
#  '60654',
#  '6jh',
#  '73301',
#  '75001',
#  '75023',
#  '75024',
#  '75201',
#  '75202',
#  '78701',
#  '78757',
#  '78758',
#  '7nh',
#  '7rl',
#  '80021',
#  '80120',
#  '80124',
#  '80202',
#  '80204',
#  '80222',
#  '80225',
#  '80230',
#  '80237',
#  '80301',
#  '80305',
#  '80309',
#  '85007',
#  '85284',
#  '85308',
#  '8jt',
#  '8sd',
#  '90023',
#  '94070',
#  '94080',
#  '94108',
#  '94404',
#  '94720',
#  '9bj',
#  '9lh',
#  'addison',
#  'albany',
#  'angeles',
#  'area',
#  'arts',
#  'atlanta',
#  'auraria',
#  'austin',
#  'az',
#  'b15',
#  'b75',
#  'berkeley',
#  'birmingham',
#  'boulder',
#  'boyle',
#  'brooklyn',
#  'broomfield',
#  'buckhead',
#  'burnett',
#  'business',
#  'ca',
#  'campus',
#  'carlos',
#  'central',
#  'chelsea',
#  'chertsey',
#  'chicago',
#  'city',
#  'coldfield',
#  'colindale',
#  'colorado',
#  'corners',
#  'coventry',
#  'creek',
#  'dallas',
#  'decatur',
#  'deer',
#  'denver',
#  'district',
#  'downtown',
#  'ec1v',
#  'edwards',
#  'field',
#  'financial',
#  'foster',
#  'francisco',
#  'ga',
#  'glendale',
#  'golden',
#  'government',
#  'hampden',
#  'heights',
#  'houston',
#  'il',
#  'interlocken',
#  'irving',
#  'kensington',
#  'lakewood',
#  'leamington',
#  'leeds',
#  'lindbergh',
#  'littleton',
#  'lodo',
#  'london',
#  'lone',
#  'loop',
#  'los',
#  'louisville',
#  'lowry',
#  'ls1',
#  'ls11',
#  'ls2',
#  'm60',
#  'manchester',
#  'near',
#  'new',
#  'north',
#  'northbrook',
#  'nw9',
#  'ny',
#  'oakland',
#  'peachtree',
#  'phoenix',
#  'plano',
#  'portland',
#  'queens',
#  'reigate',
#  'san',
#  'se1',
#  'seattle',
#  'shoal',
#  'singapore',
#  'skipton',
#  'slough',
#  'south',
#  'southeastern',
#  'spa',
#  'st',
#  'stafford',
#  'sutton',
#  'tempe',
#  'tree',
#  'tx',
#  'university',
#  'valley',
#  'w10',
#  'w1d',
#  'wa',
#  'west',
#  'westminster',
#  'yo26',
#  'york']

# %%
pipe_loc_log['logisticregression'].coef_[0]
# Out:
# array([-0.1641592 ,  0.69267086, -0.20022246, -0.17995464,  0.18718554,
#        -0.24062215, -0.17257534, -0.22333473,  0.54391775, -0.16802487,
#         0.67482753, -0.48446354,  0.20977799, -0.15479926, -0.08003276,
#         0.23317646, -0.26992491, -0.12666805, -0.10005903, -0.10005903,
#         0.46086149, -0.10616949,  0.70488119, -0.09781014, -0.24523518,
#         0.40471633,  0.29188756, -0.25382696,  0.38172466, -0.25812282,
#        -0.59659534,  0.55412089, -0.06313008, -0.29500337,  0.6702949 ,
#        -0.11211369, -0.2432227 ,  0.59615864,  0.47438531,  0.26212888,
#        -0.23656606, -0.2312681 ,  0.23317646,  0.18718554, -0.11742253,
#        -0.1534316 ,  0.512801  , -0.10640648, -0.20462079,  0.50096453,
#         0.20977799,  0.23317646, -0.12666805, -0.17995464, -0.3997854 ,
#         0.14064672, -0.10616949, -0.35508291,  0.55412089, -0.27941564,
#        -0.13534453,  0.24832068,  0.29188756,  0.50096453,  1.14071403,
#        -0.61099256, -0.11742253, -0.4344009 ,  0.04826216, -0.16802487,
#        -0.24523518, -0.48123671, -0.724609  , -0.17995464, -0.1534316 ,
#         0.37705081, -0.1641592 ,  0.45637475, -0.7769879 ,  0.05750808,
#         0.29188756,  0.38172466,  0.47438531, -0.17257534,  0.76344932,
#        -0.09781014,  0.0314114 , -0.24062215, -0.2312681 , -1.18507974,
#        -0.41290583,  0.24092431,  0.20977799, -0.26992491,  0.6702949 ,
#        -0.10640648, -0.20462079, -0.24184407, -0.7682804 , -0.2312681 ,
#         0.45637475,  0.46086149,  0.11921301, -0.11742253, -0.2533361 ,
#        -1.25108977, -0.57096143, -0.34926685,  0.4471032 , -0.29500337,
#         0.38172466,  1.00540198,  0.54391775,  0.38172466, -0.11535863,
#         1.1881102 , -0.25812282, -0.15479926, -0.3997854 , -0.34779621,
#         0.6702949 ,  0.23317646,  0.23317646,  0.23317646,  0.59617269,
#         1.07951801, -0.08003276, -0.54723693, -0.11203902, -0.47410187,
#         0.38172466, -0.46892162, -0.22589167, -0.17257534,  0.61434512,
#        -0.41898079, -0.34779621,  0.69267086, -0.34779621, -0.39527566,
#         0.37437108, -0.29500337, -0.09781014, -0.59000675,  0.45637475,
#         0.45637475,  1.07911721, -0.12345526,  0.38172466, -0.26992491,
#         0.45637475,  0.29188756, -0.51842155, -0.25812282, -1.39625603,
#        -0.09475356, -0.2312681 ,  0.20977799, -0.48446354, -0.29500337,
#         0.24091448, -0.30208911,  0.40471633, -0.1425206 ])

# %%
coefficients = pd.DataFrame(zip(feature_names, pipe_loc_log['logisticregression'].coef_[0]), columns=['name', 'coef'])

# %%
coefficients.sort_values(by='coef', ascending=False)
# Out:
#            name      coef
# 115      london  1.188110
# 64   birmingham  1.140714
# 125  manchester  1.079518
# 146       south  1.079117
# 111       leeds  1.005402
# ..          ...       ...
# 98           ga -0.768280
# 78      chicago -0.776988
# 89       denver -1.185080
# 105          il -1.251090
# 154          tx -1.396256
#
# [164 rows x 2 columns]

# %% [markdown]
# ##### test using all available variables

# %% [markdown]
# ##### set up the X, y and train-test sets

# %%
jobs_test = jobs.copy()

# %%
y = jobs_test.pop('median_high_low')

# %%
X = jobs_test[['title', 'company', 'location']]

# %%
X = jobs_test[['title', 'company', 'location', 'country']]

# %%
X
# Out:
#                                                  title  \
# 0                                       data scientist
# 1    city research scientist i / data analyst, bure...
# 2            data scientist - nationwide opportunities
# 3    city research scientist i / data and technolog...
# 4                  senior etl developer & data analyst
# ..                                                 ...
# 324  senior data engineer (machine learning & ai us...
# 325  senior linux/devops engineer with focus on big...
# 326                              senior data scientist
# 327                   senior digital analytics manager
# 328  polyglot engineer (ai start-up) - python/ gola...
#
#                              company            location  country
# 0                    fire department  brooklyn, ny 11201      usa
# 1      dept of health/mental hygiene    queens, ny 11101      usa
# 2          amazon web services, inc.        new york, ny      usa
# 3      dept of health/mental hygiene    queens, ny 11101      usa
# 4        hra/dept of social services        brooklyn, ny      usa
# ..                               ...                 ...      ...
# 324                nuvola resourcing            chertsey  england
# 325                    linux recruit              london  england
# 326                        consortia              london  england
# 327          digital republic talent              london  england
# 328  gcs recruitment specialists ltd              london  england
#
# [329 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %% [markdown]
# Since there is much variance in related job titles for the job posts, and also post codes
#
# Upon looking at unique values for the Company column, they seemed to be well standardised and there didn't seem much need to use NLP on the column since all instances of the same company would be recognised under one dummy heading.
#
# However, after reviewing the difference in scores between OneHotEncoder and CountVectorizer used on the company columns, both test and train scores whereby the Company column has been CountVectorized turn out better. Therefore NLP has been used on all text columns: Title, Company and Location.

# %% [markdown]
# ##### decision tree pipeline

# %%
cvec_title = CountVectorizer(stop_words='english')
cvec_company = CountVectorizer(stop_words='english')
cvec_location = CountVectorizer(stop_words='english', max_df=0.9, min_df=1)
ohe = OneHotEncoder(handle_unknown='ignore')
dtc = DecisionTreeClassifier()

# %%
col_trans = ColumnTransformer([('title', cvec_title, 'title'), ('company', cvec_company, 'company'), ('location', cvec_location, 'location'), ('country', ohe, ['country'])], remainder='passthrough')

# %%
pipe_dtc = make_pipeline(col_trans, dtc)

# %%
pipe_dtc.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('title',
#                                                   CountVectorizer(stop_words='english'),
#                                                   'title'),
#                                                  ('company',
#                                                   CountVectorizer(stop_words='english'),
#                                                   'company'),
#                                                  ('location',
#                                                   CountVectorizer(max_df=0.9,
#                                                                   stop_words='english'),
#                                                   'location'),
#                                                  ('country',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['country'])])),
#                 ('decisiontreeclassifier', DecisionTreeClassifier())])

# %%
pipe_dtc.score(X_train, y_train)
# Out:
# 0.9961977186311787

# %%
pipe_dtc.score(X_test, y_test)
# Out:
# 0.8181818181818182

# %%
# CVEC
# Train
# 0.9961977186311787

# Test
# 0.7878787878787878

# WITHOUT COUNTRY

# OHE
# Train
# 0.9961977186311787

# Test
# 0.7727272727272727

# %% [markdown]
# ##### logistic regression pipeline

# %%
cvec_title = CountVectorizer(stop_words='english')
cvec_company = CountVectorizer(stop_words='english')
cvec_location = CountVectorizer(stop_words='english', max_df=0.9, min_df=1)
ohe = OneHotEncoder(handle_unknown='ignore')
log = LogisticRegression()

# %%
col_trans = ColumnTransformer([('title', cvec_title, 'title'), ('company', cvec_company, 'company'), ('location', cvec_location, 'location'), ('country', ohe, ['country'])], remainder='passthrough')

# %%
pipe_log = make_pipeline(col_trans, log)

# %%
pipe_log.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('title',
#                                                   CountVectorizer(stop_words='english'),
#                                                   'title'),
#                                                  ('company',
#                                                   CountVectorizer(stop_words='english'),
#                                                   'company'),
#                                                  ('location',
#                                                   CountVectorizer(max_df=0.9,
#                                                                   stop_words='english'),
#                                                   'location'),
#                                                  ('country',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['country'])])),
#                 ('logisticregression', LogisticRegression())])

# %%
pipe_log.score(X_train, y_train)
# Out:
# 0.9657794676806084

# %%
pipe_log.score(X_test, y_test)
# Out:
# 0.7878787878787878

# %%
# ohe company
# train
# 0.9581749049429658
# test
# 0.7424242424242424

# WITHOUT COUNTRY

# cvec
# train
# 0.9695817490494296

# test
# 0.7575757575757576

# %% [markdown]
# ### Now onto the Ensemble Methods

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #### Random Forest

# %%
rfc = RandomForestClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=500, max_depth=20, n_jobs=-2)

# %%
rfc_pipe = make_pipeline(col_trans, rfc).fit(X_train, y_train)

# %%
rfc_pipe.score(X_train, y_train)
# Out:
# 0.9771863117870723

# %%
rfc_pipe.score(X_test, y_test)
# Out:
# 0.8181818181818182

# %% [markdown]
# ##### Grid Search on Random Forest

# %%
# rfc_pipe.get_params()

# %%
params = {'randomforestclassifier__ccp_alpha': [0.0, 0.1],
          'randomforestclassifier__max_depth': [i for i in range(7, 20)],
          'randomforestclassifier__min_impurity_decrease': [0.0, 0.1],
          'randomforestclassifier__min_samples_leaf': [1, 2, 3],
          'randomforestclassifier__min_samples_split': [2, 3, 4, 5],
          'randomforestclassifier__min_weight_fraction_leaf': [0.0],
          'randomforestclassifier__n_estimators': [500, 600, 700],
          'randomforestclassifier__oob_score': [True, False],
          'randomforestclassifier__random_state': [0],
          'randomforestclassifier__verbose': [2]}

# %%
gs_rfc = GridSearchCV(rfc_pipe, params, cv=5)

# %%
gs_rfc.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 378 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.5s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.5s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.4s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 379 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done 495 out of 500 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:   38.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 318 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.2s finished
# ...
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 346 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-2)]: Done 156 tasks      | elapsed:    0.2s
# building tree 1 of 500
# building tree 2 of 500building tree 3 of 500
#
# building tree 4 of 500
# building tree 5 of 500
# building tree 6 of 500
# building tree 7 of 500
# building tree 8 of 500
# building tree 9 of 500
# building tree 10 of 500building tree 11 of 500
# building tree 12 of 500
#
# building tree 13 of 500
# building tree 14 of 500building tree 15 of 500
#
# building tree 16 of 500building tree 17 of 500building tree 18 of 500
#
#
# building tree 19 of 500
# building tree 20 of 500
# building tree 21 of 500
# building tree 22 of 500building tree 23 of 500
#
# building tree 24 of 500
# building tree 25 of 500building tree 26 of 500
#
# building tree 27 of 500
# building tree 28 of 500
# building tree 29 of 500
# building tree 30 of 500
# building tree 31 of 500building tree 32 of 500
#
# building tree 33 of 500
# building tree 34 of 500
# building tree 35 of 500
# building tree 36 of 500
# building tree 37 of 500
# building tree 38 of 500building tree 39 of 500
#
# building tree 40 of 500
# building tree 41 of 500
# building tree 42 of 500
# building tree 43 of 500
# building tree 44 of 500
# building tree 45 of 500
# building tree 46 of 500
# building tree 47 of 500
# building tree 48 of 500
# building tree 49 of 500
# building tree 50 of 500
# building tree 51 of 500
# building tree 52 of 500
# building tree 53 of 500
# building tree 54 of 500
# building tree 55 of 500
# building tree 56 of 500
# building tree 57 of 500
# building tree 58 of 500
# building tree 59 of 500building tree 60 of 500
#
# building tree 61 of 500
# building tree 62 of 500building tree 63 of 500
# building tree 64 of 500
#
# building tree 65 of 500
# building tree 66 of 500building tree 67 of 500
#
# building tree 68 of 500building tree 69 of 500
#
# building tree 70 of 500
# building tree 71 of 500
# building tree 72 of 500building tree 73 of 500
#
# building tree 74 of 500
# building tree 75 of 500
# building tree 76 of 500
# building tree 77 of 500
# building tree 78 of 500building tree 79 of 500
#
# building tree 80 of 500
# building tree 81 of 500building tree 82 of 500
#
# building tree 83 of 500building tree 84 of 500
#
# building tree 85 of 500
# building tree 86 of 500building tree 87 of 500building tree 88 of 500
#
#
# building tree 89 of 500
# building tree 90 of 500
# building tree 91 of 500
# building tree 92 of 500
# building tree 93 of 500building tree 94 of 500
#
# building tree 95 of 500building tree 96 of 500building tree 97 of 500
#
#
# building tree 98 of 500
# building tree 99 of 500building tree 100 of 500
#
# building tree 101 of 500
# building tree 102 of 500
# building tree 103 of 500
# building tree 104 of 500
# building tree 105 of 500
# building tree 106 of 500building tree 107 of 500
#
# building tree 108 of 500
# building tree 109 of 500
# building tree 110 of 500building tree 111 of 500
#
# building tree 112 of 500
# building tree 113 of 500
# building tree 114 of 500
# building tree 115 of 500
# building tree 116 of 500
# building tree 117 of 500
# building tree 118 of 500building tree 119 of 500
#
# building tree 120 of 500
# building tree 121 of 500
# building tree 122 of 500building tree 123 of 500
#
# building tree 124 of 500
# building tree 125 of 500
# building tree 126 of 500
# building tree 127 of 500
# building tree 128 of 500
# building tree 129 of 500
# building tree 130 of 500
# building tree 131 of 500
# building tree 132 of 500
# building tree 133 of 500
# building tree 134 of 500building tree 135 of 500
# building tree 136 of 500
#
# building tree 137 of 500
# building tree 138 of 500
# building tree 139 of 500
# building tree 140 of 500
# building tree 141 of 500building tree 142 of 500
#
# building tree 143 of 500
# building tree 144 of 500
# building tree 145 of 500
# building tree 146 of 500
# building tree 147 of 500
# building tree 148 of 500
# building tree 149 of 500
# building tree 150 of 500
# building tree 151 of 500
# building tree 152 of 500
# building tree 153 of 500
# building tree 154 of 500
# building tree 155 of 500
# building tree 156 of 500
# building tree 157 of 500
# building tree 158 of 500
# building tree 159 of 500
# building tree 160 of 500
# building tree 161 of 500
# building tree 162 of 500
# building tree 163 of 500
# building tree 164 of 500
# building tree 165 of 500
# building tree 166 of 500
# building tree 167 of 500
# building tree 168 of 500building tree 169 of 500
#
# building tree 170 of 500
# building tree 171 of 500building tree 172 of 500building tree 173 of 500
#
#
# building tree 174 of 500building tree 175 of 500building tree 176 of 500
#
#
# building tree 177 of 500building tree 178 of 500
#
# building tree 179 of 500
# building tree 180 of 500
# building tree 181 of 500
# building tree 182 of 500
# building tree 183 of 500
# building tree 184 of 500building tree 185 of 500
#
# building tree 186 of 500
# building tree 187 of 500
# building tree 188 of 500
# building tree 189 of 500
# building tree 190 of 500
# building tree 191 of 500
# building tree 192 of 500
# building tree 193 of 500
# building tree 194 of 500
# building tree 195 of 500
# building tree 196 of 500
# building tree 197 of 500building tree 198 of 500
# building tree 199 of 500
#
# building tree 200 of 500building tree 201 of 500
#
# building tree 202 of 500
# building tree 203 of 500
# building tree 204 of 500building tree 205 of 500
#
# building tree 206 of 500
# building tree 207 of 500building tree 208 of 500
#
# building tree 209 of 500
# building tree 210 of 500
# building tree 211 of 500
# building tree 212 of 500
# building tree 213 of 500building tree 214 of 500
#
# building tree 215 of 500
# building tree 216 of 500
# building tree 217 of 500
# building tree 218 of 500
# building tree 219 of 500
# building tree 220 of 500
# building tree 221 of 500
# building tree 222 of 500
# building tree 223 of 500
# building tree 224 of 500
# building tree 225 of 500
# building tree 226 of 500
# building tree 227 of 500
# building tree 228 of 500
# building tree 229 of 500
# building tree 230 of 500
# building tree 231 of 500
# building tree 232 of 500
# building tree 233 of 500
# building tree 234 of 500
# building tree 235 of 500
# building tree 236 of 500
# building tree 237 of 500
# building tree 238 of 500
# building tree 239 of 500
# building tree 240 of 500
# building tree 241 of 500
# building tree 242 of 500
# building tree 243 of 500building tree 244 of 500
#
# building tree 245 of 500
# building tree 246 of 500
# building tree 247 of 500
# building tree 248 of 500
# building tree 249 of 500building tree 250 of 500
# building tree 251 of 500
#
# building tree 252 of 500
# building tree 253 of 500
# building tree 254 of 500
# building tree 255 of 500
# building tree 256 of 500
# building tree 257 of 500
# building tree 258 of 500
# building tree 259 of 500
# building tree 260 of 500
# building tree 261 of 500
# building tree 262 of 500
# building tree 263 of 500
# building tree 264 of 500
# building tree 265 of 500
# building tree 266 of 500
# building tree 267 of 500
# building tree 268 of 500
# building tree 269 of 500
# building tree 270 of 500
# building tree 271 of 500
# building tree 272 of 500
# building tree 273 of 500
# building tree 274 of 500building tree 275 of 500building tree 276 of 500
#
#
# building tree 277 of 500
# building tree 278 of 500building tree 279 of 500
#
# building tree 280 of 500
# building tree 281 of 500
# building tree 282 of 500
# building tree 283 of 500
# building tree 284 of 500
# building tree 285 of 500
# building tree 286 of 500building tree 287 of 500
#
# building tree 288 of 500
# building tree 289 of 500building tree 290 of 500
# building tree 291 of 500
#
# building tree 292 of 500building tree 293 of 500
#
# building tree 294 of 500
# building tree 295 of 500
# building tree 296 of 500
# building tree 297 of 500
# building tree 298 of 500
# building tree 299 of 500
# building tree 300 of 500
# building tree 301 of 500building tree 302 of 500
#
# building tree 303 of 500
# building tree 304 of 500
# building tree 305 of 500
# building tree 306 of 500
# building tree 307 of 500
# building tree 308 of 500
# building tree 309 of 500
# building tree 310 of 500
# building tree 311 of 500building tree 312 of 500
#
# building tree 313 of 500
# building tree 314 of 500
# building tree 315 of 500
# building tree 316 of 500
# building tree 317 of 500
# building tree 318 of 500
# building tree 319 of 500
# building tree 320 of 500
# building tree 321 of 500building tree 322 of 500
#
# building tree 323 of 500
# building tree 324 of 500
# building tree 325 of 500
# building tree 326 of 500building tree 327 of 500
#
# building tree 328 of 500
# building tree 329 of 500
# building tree 330 of 500building tree 331 of 500
#
# building tree 332 of 500building tree 333 of 500
#
# building tree 334 of 500
# building tree 335 of 500building tree 336 of 500
# building tree 337 of 500
#
# building tree 338 of 500
# building tree 339 of 500
# building tree 340 of 500
# building tree 341 of 500
# building tree 342 of 500
# building tree 343 of 500
# building tree 344 of 500
# building tree 345 of 500
# building tree 346 of 500
# building tree 347 of 500
# building tree 348 of 500
# building tree 349 of 500
# building tree 350 of 500
# building tree 351 of 500building tree 352 of 500
#
# building tree 353 of 500
# building tree 354 of 500
# building tree 355 of 500
# building tree 356 of 500
# building tree 357 of 500
# building tree 358 of 500
# building tree 359 of 500
# building tree 360 of 500
# building tree 361 of 500
# building tree 362 of 500
# building tree 363 of 500
# building tree 364 of 500
# building tree 365 of 500
# building tree 366 of 500
# building tree 367 of 500
# building tree 368 of 500
# building tree 369 of 500
# building tree 370 of 500
# building tree 371 of 500
# building tree 372 of 500
# building tree 373 of 500
# building tree 374 of 500
# building tree 375 of 500
# building tree 376 of 500
# building tree 377 of 500
# building tree 378 of 500building tree 379 of 500
# building tree 380 of 500
#
# building tree 381 of 500
# building tree 382 of 500
# building tree 383 of 500
# building tree 384 of 500
# building tree 385 of 500
# building tree 386 of 500
# building tree 387 of 500
# [Parallel(n_jobs=-2)]: Done 359 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done 500 out of 500 | elapsed:    0.5s finished
# building tree 388 of 500
# building tree 389 of 500
# building tree 390 of 500building tree 391 of 500
# building tree 392 of 500
#
# building tree 393 of 500
# building tree 394 of 500
# building tree 395 of 500
# building tree 396 of 500
# building tree 397 of 500
# building tree 398 of 500
# building tree 399 of 500
# building tree 400 of 500
# building tree 401 of 500
# building tree 402 of 500building tree 403 of 500
#
# building tree 404 of 500
# building tree 405 of 500
# building tree 406 of 500
# building tree 407 of 500
# building tree 408 of 500
# building tree 409 of 500
# building tree 410 of 500
# building tree 411 of 500
# building tree 412 of 500
# building tree 413 of 500building tree 414 of 500
#
# building tree 415 of 500building tree 416 of 500
#
# building tree 417 of 500
# building tree 418 of 500
# building tree 419 of 500
# building tree 420 of 500
# building tree 421 of 500building tree 422 of 500
#
# building tree 423 of 500
# building tree 424 of 500building tree 425 of 500
#
# building tree 426 of 500
# building tree 427 of 500
# building tree 428 of 500building tree 429 of 500
#
# building tree 430 of 500
# building tree 431 of 500
# building tree 432 of 500
# building tree 433 of 500
# building tree 434 of 500
# building tree 435 of 500
# building tree 436 of 500
# building tree 437 of 500
# building tree 438 of 500
# building tree 439 of 500building tree 440 of 500
#
# building tree 441 of 500
# building tree 442 of 500
# building tree 443 of 500
# building tree 444 of 500building tree 445 of 500building tree 446 of 500
#
#
# building tree 447 of 500
# building tree 448 of 500
# building tree 449 of 500
# building tree 450 of 500
# building tree 451 of 500
# building tree 452 of 500
# building tree 453 of 500
# building tree 454 of 500
# building tree 455 of 500
# building tree 456 of 500building tree 457 of 500
#
# building tree 458 of 500
# building tree 459 of 500
# building tree 460 of 500
# building tree 461 of 500
# building tree 462 of 500
# building tree 463 of 500
# building tree 464 of 500
# building tree 465 of 500
# building tree 466 of 500
# building tree 467 of 500
# building tree 468 of 500
# building tree 469 of 500
# building tree 470 of 500
# building tree 471 of 500building tree 472 of 500
#
# building tree 473 of 500
# building tree 474 of 500
# building tree 475 of 500building tree 476 of 500
#
# building tree 477 of 500
# building tree 478 of 500
# building tree 479 of 500
# building tree 480 of 500building tree 481 of 500
#
# building tree 482 of 500
# building tree 483 of 500building tree 484 of 500
#
# building tree 485 of 500
# building tree 486 of 500
# building tree 487 of 500
# building tree 488 of 500
# building tree 489 of 500building tree 490 of 500
#
# building tree 491 of 500
# building tree 492 of 500
# building tree 493 of 500
# building tree 494 of 500
# building tree 495 of 500
# building tree 496 of 500
# building tree 497 of 500
# building tree 498 of 500
# building tree 499 of 500
# building tree 500 of 500
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('title',
#                                                                          CountVectorizer(stop_words='english'),
#                                                                          'title'),
#                                                                         ('company',
#                                                                          CountVectorizer(stop_words='english'),
#                                                                          'company'),
#                                                                         ('location',
#                                                                          CountVectorizer(max_df=0.9,
#                                                                                          stop_words='english'),
#                                                                          'location'),
#                                                                         ('country',
#                                                                          OneHotEncoder(handle_unknown=...
#                                                                            0.1,
#                                                                            0.2,
#                                                                            0.3],
#                          'randomforestclassifier__min_samples_leaf': [1, 2, 3],
#                          'randomforestclassifier__min_samples_split': [2, 3, 4,
#                                                                        5],
#                          'randomforestclassifier__min_weight_fraction_leaf': [0.0],
#                          'randomforestclassifier__n_estimators': [500],
#                          'randomforestclassifier__oob_score': [True, False],
#                          'randomforestclassifier__random_state': [0],
#                          'randomforestclassifier__verbose': [2]})

# %%
gs_rfc.best_params_
# Out:
# {'randomforestclassifier__ccp_alpha': 0.0,
#  'randomforestclassifier__max_depth': 7,
#  'randomforestclassifier__min_impurity_decrease': 0.0,
#  'randomforestclassifier__min_samples_leaf': 1,
#  'randomforestclassifier__min_samples_split': 2,
#  'randomforestclassifier__min_weight_fraction_leaf': 0.0,
#  'randomforestclassifier__n_estimators': 500,
#  'randomforestclassifier__oob_score': True,
#  'randomforestclassifier__random_state': 0,
#  'randomforestclassifier__verbose': 2}

# %%
gs_rfc_model = gs_rfc.best_estimator_

# %%
gs_rfc_model.score(X_train, y_train)
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# 0.8326996197718631

# %%
gs_rfc_model.score(X_test, y_test)
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 156 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 359 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 500 out of 500 | elapsed:    0.1s finished
# 0.803030303030303

# %% [markdown]
# ##### Notes

# %% [markdown]
# Strangely, even given the same input parameters as the original Random Forest pipeline, the tuned model's scores are considerably lower on the training score and marginally lower on the test score.

# %% [markdown]
# #### Gradient Boost

# %%
gbc = GradientBoostingClassifier(base_estimator=LogisticRegression(), max_depth=45, n_estimators=500)

# %%
gbc_pipe = make_pipeline(col_trans, gbc).fit(X_train, y_train)

# %%
gbc_pipe.score(X_train, y_train)
# Out:
# 0.9961977186311787

# %%
gbc_pipe.score(X_test, y_test)
# Out:
# 0.8787878787878788

# %% [markdown]
# Start by ONLY using the location as a feature. DONE
#
# Use at least two different classifiers you find suitable. DONE
#
# Remember that scaling your features might be necessary. NOT DONE
#
# Display the coefficients/feature importances and write a short summary of what they mean. NOT DONE - COEFS PAIRED WITH THE FEATURE NAMES BUT NOT WRITTEN UP FOR LOG AND NOT DONE AT ALL FOR DECISION TREE
#
# Create a few new variables in your dataframe to represent interesting features of a job title (e.g. whether 'Senior' or 'Manager' is in the title). ONE HOT / COUNT VEC - DOUBLE CHECK THIS
#
# Incorporate other text features from the title or summary that you believe will predict the salary. NOT DONE
#
# Then build new classification models including also those features. Do they add any value? YES THEY ADD VALUE - DONE THE BUILDING OF THE MODELS, CHECK AGAIN WITH THE FEATURES
#
# Tune your models by testing parameter ranges, regularization strengths, etc. Discuss how that affects your models. MODEL TUNING SET UP. STILL TESTING.
#
# Discuss model coefficients or feature importances as applicable. NOT DONE

# %% [markdown]
# ##### Grid Search on Gradient Boost

# %%
gbc_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('title', CountVectorizer(stop_words='english'),
#                                     'title'),
#                                    ('company',
#                                     CountVectorizer(stop_words='english'),
#                                     'company'),
#                                    ('location',
#                                     CountVectorizer(max_df=0.9,
#                                                     stop_words='english'),
#                                     'location'),
#                                    ('country',
#                                     OneHotEncoder(handle_unknown='ignore'),
#                                     ['country'])])),
#   ('gradientboostingclassifier',
#    GradientBoostingClassifier(max_depth=45, n_estimators=500))],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(remainder='passthrough',
#                    transformers=[('title', CountVectorizer(stop_words='english'),
#                                   'title'),
#                                  ('company',
#                                   CountVectorizer(stop_words='english'),
#                                   'company'),
#                                  ('location',
#                                   CountVectorizer(max_df=0.9,
#                                                   stop_words='english'),
#                                   'location'),
#                                  ('country',
#                                   OneHotEncoder(handle_unknown='ignore'),
#                                   ['country'])]),
#  'gradientboostingclassifier': GradientBoostingClassifier(max_depth=45, n_estimators=500),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'passthrough',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('title',
#    CountVectorizer(stop_words='english'),
#    'title'),
#   ('company', CountVectorizer(stop_words='english'), 'company'),
#   ('location', CountVectorizer(max_df=0.9, stop_words='english'), 'location'),
#   ('country', OneHotEncoder(handle_unknown='ignore'), ['country'])],
#  'columntransformer__verbose': False,
#  'columntransformer__title': CountVectorizer(stop_words='english'),
#  'columntransformer__company': CountVectorizer(stop_words='english'),
#  'columntransformer__location': CountVectorizer(max_df=0.9, stop_words='english'),
#  'columntransformer__country': OneHotEncoder(handle_unknown='ignore'),
#  'columntransformer__title__analyzer': 'word',
#  'columntransformer__title__binary': False,
#  'columntransformer__title__decode_error': 'strict',
#  'columntransformer__title__dtype': numpy.int64,
#  'columntransformer__title__encoding': 'utf-8',
#  'columntransformer__title__input': 'content',
#  'columntransformer__title__lowercase': True,
#  'columntransformer__title__max_df': 1.0,
#  'columntransformer__title__max_features': None,
#  'columntransformer__title__min_df': 1,
#  'columntransformer__title__ngram_range': (1, 1),
#  'columntransformer__title__preprocessor': None,
#  'columntransformer__title__stop_words': 'english',
#  'columntransformer__title__strip_accents': None,
#  'columntransformer__title__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'columntransformer__title__tokenizer': None,
#  'columntransformer__title__vocabulary': None,
#  'columntransformer__company__analyzer': 'word',
#  'columntransformer__company__binary': False,
#  'columntransformer__company__decode_error': 'strict',
#  'columntransformer__company__dtype': numpy.int64,
#  'columntransformer__company__encoding': 'utf-8',
#  'columntransformer__company__input': 'content',
#  'columntransformer__company__lowercase': True,
#  'columntransformer__company__max_df': 1.0,
#  'columntransformer__company__max_features': None,
#  'columntransformer__company__min_df': 1,
#  'columntransformer__company__ngram_range': (1, 1),
#  'columntransformer__company__preprocessor': None,
#  'columntransformer__company__stop_words': 'english',
#  'columntransformer__company__strip_accents': None,
#  'columntransformer__company__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'columntransformer__company__tokenizer': None,
#  'columntransformer__company__vocabulary': None,
#  'columntransformer__location__analyzer': 'word',
#  'columntransformer__location__binary': False,
#  'columntransformer__location__decode_error': 'strict',
#  'columntransformer__location__dtype': numpy.int64,
#  'columntransformer__location__encoding': 'utf-8',
#  'columntransformer__location__input': 'content',
#  'columntransformer__location__lowercase': True,
#  'columntransformer__location__max_df': 0.9,
#  'columntransformer__location__max_features': None,
#  'columntransformer__location__min_df': 1,
#  'columntransformer__location__ngram_range': (1, 1),
#  'columntransformer__location__preprocessor': None,
#  'columntransformer__location__stop_words': 'english',
#  'columntransformer__location__strip_accents': None,
#  'columntransformer__location__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'columntransformer__location__tokenizer': None,
#  'columntransformer__location__vocabulary': None,
#  'columntransformer__country__categories': 'auto',
#  'columntransformer__country__drop': None,
#  'columntransformer__country__dtype': numpy.float64,
#  'columntransformer__country__handle_unknown': 'ignore',
#  'columntransformer__country__sparse': True,
#  'gradientboostingclassifier__ccp_alpha': 0.0,
#  'gradientboostingclassifier__criterion': 'friedman_mse',
#  'gradientboostingclassifier__init': None,
#  'gradientboostingclassifier__learning_rate': 0.1,
#  'gradientboostingclassifier__loss': 'deviance',
#  'gradientboostingclassifier__max_depth': 45,
#  'gradientboostingclassifier__max_features': None,
#  'gradientboostingclassifier__max_leaf_nodes': None,
#  'gradientboostingclassifier__min_impurity_decrease': 0.0,
#  'gradientboostingclassifier__min_impurity_split': None,
#  'gradientboostingclassifier__min_samples_leaf': 1,
#  'gradientboostingclassifier__min_samples_split': 2,
#  'gradientboostingclassifier__min_weight_fraction_leaf': 0.0,
#  'gradientboostingclassifier__n_estimators': 500,
#  'gradientboostingclassifier__n_iter_no_change': None,
#  'gradientboostingclassifier__presort': 'deprecated',
#  'gradientboostingclassifier__random_state': None,
#  'gradientboostingclassifier__subsample': 1.0,
#  'gradientboostingclassifier__tol': 0.0001,
#  'gradientboostingclassifier__validation_fraction': 0.1,
#  'gradientboostingclassifier__verbose': 0,
#  'gradientboostingclassifier__warm_start': False}

# %%
gbc_pipe['']

# %%
params = {'gradientboostingclassifier__ccp_alpha': 0.0,
          'gradientboostingclassifier__criterion': 'friedman_mse',
          'gradientboostingclassifier__init': None,
          'gradientboostingclassifier__learning_rate': 0.1,
          'gradientboostingclassifier__loss': 'deviance',
          'gradientboostingclassifier__max_depth': 45,
          'gradientboostingclassifier__max_features': None,
          'gradientboostingclassifier__max_leaf_nodes': None,
          'gradientboostingclassifier__min_impurity_decrease': 0.0,
          'gradientboostingclassifier__min_impurity_split': None,
          'gradientboostingclassifier__min_samples_leaf': 1,
          'gradientboostingclassifier__min_samples_split': 2,
          'gradientboostingclassifier__min_weight_fraction_leaf': 0.0,
          'gradientboostingclassifier__n_estimators': 500,
          'gradientboostingclassifier__n_iter_no_change': None,
          'gradientboostingclassifier__presort': 'deprecated',
          'gradientboostingclassifier__random_state': None,
          'gradientboostingclassifier__subsample': 1.0,
          'gradientboostingclassifier__tol': 0.0001,
          'gradientboostingclassifier__validation_fraction': 0.1,
          'gradientboostingclassifier__verbose': 0,
          'gradientboostingclassifier__warm_start': False}

# %%
gs_gbc = GridSearchCV(rfc_pipe)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-409-c1dfc682143e> in <module>
# ----> 1 gs_gbc = GridSearchCV(rfc_pipe)
#
# NameError: name 'GridSearchCV' is not defined

# %% [markdown]
# ### Model evaluation:
#
# Your boss would rather tell a client incorrectly that they would get a lower salary job than tell a client incorrectly that they would get a high salary job. Adjust one of your models to ease his mind, and explain what it is doing and any tradeoffs.
#
#
# - Use cross-validation to evaluate your models.
# - Evaluate the accuracy, AUC, precision and recall of the models.
# - Plot the ROC and precision-recall curves for at least one of your models.

# %%
## YOUR CODE HERE

from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, recall_score, precision_score, f1_score

# %%
cross_val_score(pipe, X_train, y_train, cv=5)
# Out:
# array([0. , 0.5, 1. , 0.5, 0.5])

# %%
_.mean()
# Out:
# 0.5

# %%
y_pred_test = pipe.predict(X_test)

# %%
confusion_matrix(y_test, y_pred_test)
# Out:
# array([[2, 0],
#        [1, 0]])

# %%
classification_report(y_test, y_pred_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-638ea571fa95> in <module>
# ----> 1 classification_report(y_test, y_pred_test)
#
# NameError: name 'classification_report' is not defined

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_test).ravel()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['Forged','Authorized'],
                      title='Confusion matrix, without normalization')

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### Bonus:
#
# - Answer the salary discussion by using your model to explain the tradeoffs between detecting high vs low salary positions.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.
# - Obtain the ROC/precision-recall curves for the different models you studied (at least the tuned model of each category) and compare.

# %%
## YOUR CODE HERE

# %% [markdown]
# Within the classes predicted by the model (High, Low), there are large disparities in responsibility within the industry landscape. It is key to understand the responsibility-reward balance when it comes the jobsearch, and although the model will help identify those salaries that are above market median, it is not to say that it is not far more important to understand the full spectrum of features that contribute to whether a job is the right job.

# %% [markdown]
# ### Summarize your results in an executive summary written for a non-technical audience.
#
# - Writeups should be at least 500-1000 words, defining any technical terms, explaining your approach, as well as any risks and limitations.

# %% [markdown]
# ##### YOUR TEXT HERE IN MARKDOWN FORMAT
#
# From the data that has been collected, only the posts detailing salary estimations have been used, with those that have provided ranges being set to mid-range values.
#
# In searching for a job, the cornerstone factors with compatibility are title, location, salary and company.
#
# For the purpose of preparing the data, any incomplete records have been dropped from the dataset. For data preprocessing, Natural Language processing has been employed using the CountVectorizer to identify keywords that associate with particular salary regions.

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### BONUS
#
# Convert your executive summary into a public blog post of at least 500 words, in which you document your approach in a tutorial for other aspiring data scientists. Link to this in your notebook.

# %%
## YOUR LINK HERE IN MARKDOWN FORMAT
